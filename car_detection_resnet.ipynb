# %% [markdown]
# **Car Make and Model Detection**
# Group:
# James Wang,
# Vincent Thai,
# Billy Kwong
#
# Project accompanied by paper
#
# Note: Run all cells in order in Google Colab order for functionality.
# Only tested on **Google Colab** with **GPU runtime**.
#
# Requires NVIDIA CUDA Support
#
# **Import all necessary packages:**

# %%
import tarfile
import os
import csv
import time
import torch
import json
from random import randint
from pathlib import Path
from PIL import Image
import PIL.Image
from scipy.io import loadmat
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision.models as models
from matplotlib.ticker import FormatStrFormatter
from google.colab.patches import cv2_imshow
import matplotlib.image as mpimg 
from matplotlib.pyplot import imshow
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# **Download and extract files from Stanford University Repo**

# %%
#Download full training data (~935 MB)
# !wget --no-check-certificate \
    http://imagenet.stanford.edu/internal/car196/cars_train.tgz \
    -O /tmp/cars_train.tgz #downloaded directory
#extract training data to /tmp/train/
train_tar = tarfile.open('/tmp/cars_train.tgz')
train_tar.extractall('/tmp/train') # specify which folder to extract to
train_tar.close()
#directory looks like /tmp/train/cars_train/
# Out:
# --2020-03-18 05:52:48--  http://imagenet.stanford.edu/internal/car196/cars_train.tgz
# Resolving imagenet.stanford.edu (imagenet.stanford.edu)... 171.64.68.16
# Connecting to imagenet.stanford.edu (imagenet.stanford.edu)|171.64.68.16|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 979269282 (934M) [application/x-gzip]
# Saving to: ‘/tmp/cars_train.tgz’
#
# /tmp/cars_train.tgz 100%[===================>] 933.90M  8.12MB/s    in 80s
#
# 2020-03-18 05:54:08 (11.7 MB/s) - ‘/tmp/cars_train.tgz’ saved [979269282/979269282]

# %%
#Download full testing data (~933MB)
# !wget --no-check-certificate \
    http://imagenet.stanford.edu/internal/car196/cars_test.tgz \
    -O /tmp/cars_test.tgz #downloaded directory
#extract testing data to tmp/test/
test_tar = tarfile.open('/tmp/cars_test.tgz')
test_tar.extractall('/tmp/test') # specify which folder to extract to
test_tar.close()
#directory looks like /tmp/test/cars_test/
# Out:
# --2020-03-18 05:54:17--  http://imagenet.stanford.edu/internal/car196/cars_test.tgz
# Resolving imagenet.stanford.edu (imagenet.stanford.edu)... 171.64.68.16
# Connecting to imagenet.stanford.edu (imagenet.stanford.edu)|171.64.68.16|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 977350468 (932M) [application/x-gzip]
# Saving to: ‘/tmp/cars_test.tgz’
#
# /tmp/cars_test.tgz  100%[===================>] 932.07M  5.83MB/s    in 2m 34s
#
# 2020-03-18 05:56:52 (6.03 MB/s) - ‘/tmp/cars_test.tgz’ saved [977350468/977350468]

# %%
#Download labels (~0.3MB)
# !wget --no-check-certificate \
    http://ai.stanford.edu/~jkrause/cars/car_devkit.tgz \
    -O /tmp/car_devkit.tgz
Path("/tmp/annos").mkdir(parents=True, exist_ok=True)
# !wget --no-check-certificate \
    https://people.ucsc.edu/~jwang402/carslabel/anno_test.csv \
    -O /tmp/annos/anno_test.csv
#extract labels to /tmp/labels/
label_tar = tarfile.open('/tmp/car_devkit.tgz')
label_tar.extractall('/tmp/labels') # specify which folder to extract to
label_tar.close()
#directory looks like /tmp/labels/devkit/
#devkit dir contains: cars_meta.mat, cars_test_annos.mat, 
#cars_train_annos.mat, eval_train.m, README, train_perfect_preds.txt
# Out:
# --2020-03-18 05:57:01--  http://ai.stanford.edu/~jkrause/cars/car_devkit.tgz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 330960 (323K) [application/x-gzip]
# Saving to: ‘/tmp/car_devkit.tgz’
#
# /tmp/car_devkit.tgz 100%[===================>] 323.20K   286KB/s    in 1.1s
#
# 2020-03-18 05:57:02 (286 KB/s) - ‘/tmp/car_devkit.tgz’ saved [330960/330960]
#
# --2020-03-18 05:57:04--  https://people.ucsc.edu/~jwang402/carslabel/anno_test.csv
# Resolving people.ucsc.edu (people.ucsc.edu)... 128.114.119.88
# Connecting to people.ucsc.edu (people.ucsc.edu)|128.114.119.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 225299 (220K) [text/csv]
# Saving to: ‘/tmp/annos/anno_test.csv’
#
# /tmp/annos/anno_tes 100%[===================>] 220.02K   385KB/s    in 0.6s
#
# 2020-03-18 05:57:05 (385 KB/s) - ‘/tmp/annos/anno_test.csv’ saved [225299/225299]

# %% [markdown]
# **Load Class Mapping**

# %%
#Classes are assigned numerical value of 1-196, each
#mapping to a string. Data from cars_meta matlab file
#This applies to all data.
meta = loadmat('/tmp/labels/devkit/cars_meta.mat')
meta.keys()
type(meta['class_names']),meta['class_names'].shape
[item.flat[0] for item in meta['class_names'][0][0]]
classes = [[row.flat[0] for row in line] for line in meta['class_names'][0]]
classDict = {}
classCount = 1
for c in classes:
    classDict.update({classCount:c[0]})
    classCount = classCount + 1
term = 0
for num, model in classDict.items():
    print('Class #', num,'Model String:', model)
    term = term + 1
    if term == 4:
        break
print('...')
# Out:
# Class # 1 Model String: AM General Hummer SUV 2000
# Class # 2 Model String: Acura RL Sedan 2012
# Class # 3 Model String: Acura TL Sedan 2012
# Class # 4 Model String: Acura TL Type-S 2008
# ...

# %% [markdown]
# **Load labels**

# %%
#LABELS FOR TRAINING DATA
#contains bbox, class, and filename
labelfile = loadmat('/tmp/labels/devkit/cars_train_annos.mat')
labelfile.keys()
type(labelfile['annotations']),labelfile['annotations'].shape
type(labelfile['annotations'][0][0]),labelfile['annotations'][0][0].shape
labelfile['annotations'][0][0]['bbox_x1'], labelfile['annotations'][0][0]['fname']
[item.flat[0] for item in labelfile['annotations'][0][0]]
"""
The following variable 'trainLabels' contains a list of labels for 
every test image the format of each element is as follows:
### bbox_x1, bbox_y1, bbox_x2, bbox_y2, class, filename
"""
trainLabels = [[row.flat[0] for row in line] for line in labelfile['annotations'][0]]
#Outputting the table for readibility with pandas
columns = ['boundingbox_x1', 'boundingbox_y1', 'boundingbox_x2', 'boundingbox_y2', 'class', 'fname']
view = pd.DataFrame(trainLabels, columns=columns)
view.head()
# Out:
#    boundingbox_x1  boundingbox_y1  ...  class      fname
# 0              39             116  ...     14  00001.jpg
# 1              36             116  ...      3  00002.jpg
# 2              85             109  ...     91  00003.jpg
# 3             621             393  ...    134  00004.jpg
# 4              14              36  ...    106  00005.jpg
#
# [5 rows x 6 columns]

# %%
#LABELS FOR TESTING DATA
#Contains bbox and filename
lf = loadmat('/tmp/labels/devkit/cars_test_annos.mat')
lf.keys()
type(lf['annotations']),lf['annotations'].shape
type(lf['annotations'][0][0]),lf['annotations'][0][0].shape
lf['annotations'][0][0]['bbox_x1'], lf['annotations'][0][0]['fname']
[item.flat[0] for item in lf['annotations'][0][0]]
"""
The following variable 'testLabels' contains a list of labels for 
every test image the format of each element is as follows:
### bbox_x1, bbox_y1, bbox_x2, bbox_y2, filename
there is no class name in this set of labels
"""
testLabels = [[row.flat[0] for row in line] for line in lf['annotations'][0]]

#Test labels class and fname
with open('/tmp/annos/anno_test.csv') as csv_file:
    read = csv.reader(csv_file, delimiter=',')
    testDict = {}
    classCount = 1
    for row in read:
        testDict.update({row[0]:row[5]})
        classCount = classCount + 1
    print(len(testDict), 'processed')
# Out:
# 8041 processed

# %%
#What labels look like for Training vs Testing after processing
print("Train Labels")
print("...")
for i in range(len(trainLabels) - 4, len(trainLabels)):
    print(trainLabels[i])
print("\nTest Labels")
print("...")
for i in range(len(testLabels) - 4, len(testLabels)):
    print(testLabels[i])
# Out:
# Train Labels
# ...
# [138, 150, 706, 523, 196, '08141.jpg']
# [26, 246, 660, 449, 163, '08142.jpg']
# [78, 526, 1489, 908, 112, '08143.jpg']
# [20, 240, 862, 677, 17, '08144.jpg']
#
# Test Labels
# ...
# [23, 18, 640, 459, '08038.jpg']
# [33, 27, 602, 252, '08039.jpg']
# [33, 142, 521, 376, '08040.jpg']
# [77, 73, 506, 380, '08041.jpg']

# %% [markdown]
# **Preprocess Images**

# %%
"""
Preprocess Training Images
Gets all training images and crops by bounding box, saves to a new directory
The directory housing training image has subdirectories named by class name
with each corresponding image in the corresponding folder
Saves ~7% of images for validation
"""
print(len(trainLabels), "images to process.")
Path("/tmp/processedTrain").mkdir(parents=True, exist_ok=True)
Path("/tmp/processedValidation").mkdir(parents=True, exist_ok=True)
count = 1
for l in trainLabels:
    print('Processing image', count, 'of', len(trainLabels))
    #bbox
    x1 = l[0]
    y1 = l[1]
    x2 = l[2]
    y2 = l[3]
    class_num = l[4]
    filename = l[5]
    address = "/tmp/train/cars_train/" + filename
    classAppend = classDict.get(class_num) + '/'
    if count < 7000:
        saveDir = "/tmp/processedTrain/" + classAppend
    else:
        saveDir = "/tmp/processedValidation/" + classAppend
    im = PIL.Image.open(address)
    region = im.crop((x1, y1, x2, y2))
    Path(saveDir).mkdir(parents=True, exist_ok=True)
    saveAddress = saveDir + filename
    region.save(saveAddress)    
    print('Saved', saveAddress)
    count = count + 1
print("------------------------")
print("Training images preprocessing complete.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Saved /tmp/processedTrain/Chevrolet HHR SS 2010/05646.jpg
# Processing image 5647 of 8144
# Saved /tmp/processedTrain/Audi TT RS Coupe 2012/05647.jpg
# Processing image 5648 of 8144
# Saved /tmp/processedTrain/Bentley Arnage Sedan 2009/05648.jpg
# Processing image 5649 of 8144
# Saved /tmp/processedTrain/Ford F-150 Regular Cab 2007/05649.jpg
# Processing image 5650 of 8144
# Saved /tmp/processedTrain/BMW 3 Series Sedan 2012/05650.jpg
# Processing image 5651 of 8144
# Saved /tmp/processedTrain/Fisker Karma Sedan 2012/05651.jpg
# Processing image 5652 of 8144
# Saved /tmp/processedTrain/MINI Cooper Roadster Convertible 2012/05652.jpg
# Processing image 5653 of 8144
# Saved /tmp/processedTrain/Dodge Dakota Crew Cab 2010/05653.jpg
# Processing image 5654 of 8144
# Saved /tmp/processedTrain/BMW 1 Series Coupe 2012/05654.jpg
# Processing image 5655 of 8144
# Saved /tmp/processedTrain/Ford Freestar Minivan 2007/05655.jpg
# Processing image 5656 of 8144
# Saved /tmp/processedTrain/Ford E-Series Wagon Van 2012/05656.jpg
# Processing image 5657 of 8144
# Saved /tmp/processedTrain/AM General Hummer SUV 2000/05657.jpg
# Processing image 5658 of 8144
# Saved /tmp/processedTrain/Chrysler PT Cruiser Convertible 2008/05658.jpg
# Processing image 5659 of 8144
# Saved /tmp/processedTrain/Ferrari FF Coupe 2012/05659.jpg
# Processing image 5660 of 8144
# Saved /tmp/processedTrain/Chevrolet Corvette ZR1 2012/05660.jpg
# Processing image 5661 of 8144
# Saved /tmp/processedTrain/Land Rover Range Rover SUV 2012/05661.jpg
# Processing image 5662 of 8144
# Saved /tmp/processedTrain/Dodge Charger Sedan 2012/05662.jpg
# Processing image 5663 of 8144
# Saved /tmp/processedTrain/Ford E-Series Wagon Van 2012/05663.jpg
# Processing image 5664 of 8144
# Saved /tmp/processedTrain/GMC Savana Van 2012/05664.jpg
# Processing image 5665 of 8144
# Saved /tmp/processedTrain/Daewoo Nubira Wagon 2002/05665.jpg
# Processing image 5666 of 8144
# Saved /tmp/processedTrain/Tesla Model S Sedan 2012/05666.jpg
# Processing image 5667 of 8144
# Saved /tmp/processedTrain/Chrysler PT Cruiser Convertible 2008/05667.jpg
# Processing image 5668 of 8144
# Saved /tmp/processedTrain/Ferrari 458 Italia Coupe 2012/05668.jpg
# Processing image 5669 of 8144
# Saved /tmp/processedTrain/Fisker Karma Sedan 2012/05669.jpg
# Processing image 5670 of 8144
# Saved /tmp/processedTrain/Bentley Continental GT Coupe 2007/05670.jpg
# Processing image 5671 of 8144
# Saved /tmp/processedTrain/Acura Integra Type R 2001/05671.jpg
# Processing image 5672 of 8144
# Saved /tmp/processedTrain/Chevrolet Traverse SUV 2012/05672.jpg
# Processing image 5673 of 8144
# Saved /tmp/processedTrain/Porsche Panamera Sedan 2012/05673.jpg
# Processing image 5674 of 8144
# Saved /tmp/processedTrain/Audi S5 Coupe 2012/05674.jpg
# Processing image 5675 of 8144
# Saved /tmp/processedTrain/Lamborghini Aventador Coupe 2012/05675.jpg
# Processing image 5676 of 8144
# Saved /tmp/processedTrain/Infiniti G Coupe IPL 2012/05676.jpg
# Processing image 5677 of 8144
# Saved /tmp/processedTrain/Mercedes-Benz Sprinter Van 2012/05677.jpg
# Processing image 5678 of 8144
# Saved /tmp/processedTrain/Nissan NV Passenger Van 2012/05678.jpg
# Processing image 5679 of 8144
# Saved /tmp/processedTrain/Volkswagen Golf Hatchback 2012/05679.jpg
# Processing image 5680 of 8144
# Saved /tmp/processedTrain/Porsche Panamera Sedan 2012/05680.jpg
# Processing image 5681 of 8144
# Saved /tmp/processedTrain/Chrysler Sebring Convertible 2010/05681.jpg
# Processing image 5682 of 8144
# Saved /tmp/processedTrain/Dodge Ram Pickup 3500 Quad Cab 2009/05682.jpg
# Processing image 5683 of 8144
# Saved /tmp/processedTrain/Bugatti Veyron 16.4 Convertible 2009/05683.jpg
# Processing image 5684 of 8144
# Saved /tmp/processedTrain/Dodge Ram Pickup 3500 Quad Cab 2009/05684.jpg
# Processing image 5685 of 8144
# Saved /tmp/processedTrain/BMW X6 SUV 2012/05685.jpg
# Processing image 5686 of 8144
# Saved /tmp/processedTrain/Dodge Caravan Minivan 1997/05686.jpg
# Processing image 5687 of 8144
# Saved /tmp/processedTrain/Land Rover Range Rover SUV 2012/05687.jpg
# Processing image 5688 of 8144
# Saved /tmp/processedTrain/Audi S4 Sedan 2007/05688.jpg
# Processing image 5689 of 8144
# Saved /tmp/processedTrain/Hyundai Tucson SUV 2012/05689.jpg
# Processing image 5690 of 8144
# Saved /tmp/processedTrain/Jeep Grand Cherokee SUV 2012/05690.jpg
# Processing image 5691 of 8144
# Saved /tmp/processedTrain/Chevrolet Cobalt SS 2010/05691.jpg
# Processing image 5692 of 8144
# Saved /tmp/processedTrain/Buick Rainier SUV 2007/05692.jpg
# Processing image 5693 of 8144
# Saved /tmp/processedTrain/Ford E-Series Wagon Van 2012/05693.jpg
# Processing image 5694 of 8144
# Saved /tmp/processedTrain/Aston Martin V8 Vantage Coupe 2012/05694.jpg
# Processing image 5695 of 8144
# Saved /tmp/processedTrain/Bentley Arnage Sedan 2009/05695.jpg
# Processing image 5696 of 8144
# Saved /tmp/processedTrain/Nissan NV Passenger Van 2012/05696.jpg
# Processing image 5697 of 8144
# Saved /tmp/processedTrain/Ford Fiesta Sedan 2012/05697.jpg
# Processing image 5698 of 8144
# Saved /tmp/processedTrain/Cadillac SRX SUV 2012/05698.jpg
# Processing image 5699 of 8144
# Saved /tmp/processedTrain/Bentley Continental GT Coupe 2007/05699.jpg
# Processing image 5700 of 8144
# Saved /tmp/processedTrain/Suzuki SX4 Hatchback 2012/05700.jpg
# Processing image 5701 of 8144
# Saved /tmp/processedTrain/Cadillac CTS-V Sedan 2012/05701.jpg
# Processing image 5702 of 8144
# Saved /tmp/processedTrain/Cadillac Escalade EXT Crew Cab 2007/05702.jpg
# Processing image 5703 of 8144
# Saved /tmp/processedTrain/Nissan NV Passenger Van 2012/05703.jpg
# Processing image 5704 of 8144
# Saved /tmp/processedTrain/GMC Canyon Extended Cab 2012/05704.jpg
# Processing image 5705 of 8144
# Saved /tmp/processedTrain/Audi S6 Sedan 2011/05705.jpg
# Processing image 5706 of 8144
# Saved /tmp/processedTrain/BMW M5 Sedan 2010/05706.jpg
# Processing image 5707 of 8144
# Saved /tmp/processedTrain/Bentley Continental Flying Spur Sedan 2007/05707.jpg
# Processing image 5708 of 8144
# Saved /tmp/processedTrain/Toyota 4Runner SUV 2012/05708.jpg
# Processing image 5709 of 8144
# Saved /tmp/processedTrain/FIAT 500 Abarth 2012/05709.jpg
# Processing image 5710 of 8144
# Saved /tmp/processedTrain/BMW ActiveHybrid 5 Sedan 2012/05710.jpg
# Processing image 5711 of 8144
# Saved /tmp/processedTrain/Nissan 240SX Coupe 1998/05711.jpg
# Processing image 5712 of 8144
# Saved /tmp/processedTrain/Honda Accord Sedan 2012/05712.jpg
# Processing image 5713 of 8144
# Saved /tmp/processedTrain/Audi 100 Wagon 1994/05713.jpg
# Processing image 5714 of 8144
# Saved /tmp/processedTrain/GMC Canyon Extended Cab 2012/05714.jpg
# Processing image 5715 of 8144
# Saved /tmp/processedTrain/Chrysler Sebring Convertible 2010/05715.jpg
# Processing image 5716 of 8144
# Saved /tmp/processedTrain/Dodge Journey SUV 2012/05716.jpg
# Processing image 5717 of 8144
# Saved /tmp/processedTrain/Audi 100 Sedan 1994/05717.jpg
# Processing image 5718 of 8144
# Saved /tmp/processedTrain/Aston Martin Virage Convertible 2012/05718.jpg
# Processing image 5719 of 8144
# Saved /tmp/processedTrain/BMW M6 Convertible 2010/05719.jpg
# Processing image 5720 of 8144
# Saved /tmp/processedTrain/BMW ActiveHybrid 5 Sedan 2012/05720.jpg
# Processing image 5721 of 8144
# Saved /tmp/processedTrain/Dodge Caravan Minivan 1997/05721.jpg
# Processing image 5722 of 8144
# Saved /tmp/processedTrain/Bentley Mulsanne Sedan 2011/05722.jpg
# Processing image 5723 of 8144
# Saved /tmp/processedTrain/Dodge Dakota Crew Cab 2010/05723.jpg
# Processing image 5724 of 8144
# Saved /tmp/processedTrain/Chevrolet Malibu Sedan 2007/05724.jpg
# Processing image 5725 of 8144
# Saved /tmp/processedTrain/Isuzu Ascender SUV 2008/05725.jpg
# Processing image 5726 of 8144
# Saved /tmp/processedTrain/Chevrolet Camaro Convertible 2012/05726.jpg
# Processing image 5727 of 8144
# Saved /tmp/processedTrain/Hyundai Azera Sedan 2012/05727.jpg
# Processing image 5728 of 8144
# Saved /tmp/processedTrain/Chrysler Aspen SUV 2009/05728.jpg
# Processing image 5729 of 8144
# Saved /tmp/processedTrain/Audi TT RS Coupe 2012/05729.jpg
# Processing image 5730 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/05730.jpg
# Processing image 5731 of 8144
# Saved /tmp/processedTrain/Dodge Durango SUV 2012/05731.jpg
# Processing image 5732 of 8144
# Saved /tmp/processedTrain/Ford F-150 Regular Cab 2012/05732.jpg
# Processing image 5733 of 8144
# Saved /tmp/processedTrain/Hyundai Accent Sedan 2012/05733.jpg
# Processing image 5734 of 8144
# Saved /tmp/processedTrain/Nissan 240SX Coupe 1998/05734.jpg
# Processing image 5735 of 8144
# Saved /tmp/processedTrain/Lamborghini Aventador Coupe 2012/05735.jpg
# Processing image 5736 of 8144
# Saved /tmp/processedTrain/Jeep Wrangler SUV 2012/05736.jpg
# Processing image 5737 of 8144
# Saved /tmp/processedTrain/Bugatti Veyron 16.4 Coupe 2009/05737.jpg
# Processing image 5738 of 8144
# Saved /tmp/processedTrain/Cadillac Escalade EXT Crew Cab 2007/05738.jpg
# Processing image 5739 of 8144
# Saved /tmp/processedTrain/Chevrolet Express Cargo Van 2007/05739.jpg
# Processing image 5740 of 8144
# Saved /tmp/processedTrain/Chevrolet Corvette Convertible 2012/05740.jpg
# Processing image 5741 of 8144
# Saved /tmp/processedTrain/Cadillac SRX SUV 2012/05741.jpg
# Processing image 5742 of 8144
# Saved /tmp/processedTrain/Scion xD Hatchback 2012/05742.jpg
# Processing image 5743 of 8144
# Saved /tmp/processedTrain/Chevrolet Tahoe Hybrid SUV 2012/05743.jpg
# Processing image 5744 of 8144
# Saved /tmp/processedTrain/Jeep Patriot SUV 2012/05744.jpg
# Processing image 5745 of 8144
# Saved /tmp/processedTrain/Chrysler 300 SRT-8 2010/05745.jpg
# Processing image 5746 of 8144
# Saved /tmp/processedTrain/Hyundai Elantra Sedan 2007/05746.jpg
# Processing image 5747 of 8144
# Saved /tmp/processedTrain/Lincoln Town Car Sedan 2011/05747.jpg
# Processing image 5748 of 8144
# Saved /tmp/processedTrain/Acura TL Sedan 2012/05748.jpg
# Processing image 5749 of 8144
# Saved /tmp/processedTrain/Toyota 4Runner SUV 2012/05749.jpg
# Processing image 5750 of 8144
# Saved /tmp/processedTrain/Suzuki Aerio Sedan 2007/05750.jpg
# Processing image 5751 of 8144
# Saved /tmp/processedTrain/GMC Savana Van 2012/05751.jpg
# Processing image 5752 of 8144
# Saved /tmp/processedTrain/Dodge Caravan Minivan 1997/05752.jpg
# Processing image 5753 of 8144
# Saved /tmp/processedTrain/Ford F-150 Regular Cab 2012/05753.jpg
# Processing image 5754 of 8144
# Saved /tmp/processedTrain/AM General Hummer SUV 2000/05754.jpg
# Processing image 5755 of 8144
# Saved /tmp/processedTrain/Hyundai Azera Sedan 2012/05755.jpg
# Processing image 5756 of 8144
# Saved /tmp/processedTrain/Lincoln Town Car Sedan 2011/05756.jpg
# Processing image 5757 of 8144
# Saved /tmp/processedTrain/HUMMER H3T Crew Cab 2010/05757.jpg
# Processing image 5758 of 8144
# Saved /tmp/processedTrain/Buick Enclave SUV 2012/05758.jpg
# Processing image 5759 of 8144
# Saved /tmp/processedTrain/Chevrolet Sonic Sedan 2012/05759.jpg
# Processing image 5760 of 8144
# Saved /tmp/processedTrain/Bugatti Veyron 16.4 Convertible 2009/05760.jpg
# Processing image 5761 of 8144
# Saved /tmp/processedTrain/Porsche Panamera Sedan 2012/05761.jpg
# Processing image 5762 of 8144
# Saved /tmp/processedTrain/Chrysler PT Cruiser Convertible 2008/05762.jpg
# Processing image 5763 of 8144
# Saved /tmp/processedTrain/Bentley Mulsanne Sedan 2011/05763.jpg
# Processing image 5764 of 8144
# Saved /tmp/processedTrain/Chrysler Town and Country Minivan 2012/05764.jpg
# Processing image 5765 of 8144
# Saved /tmp/processedTrain/Dodge Charger SRT-8 2009/05765.jpg
# Processing image 5766 of 8144
# Saved /tmp/processedTrain/Volkswagen Golf Hatchback 2012/05766.jpg
# Processing image 5767 of 8144
# Saved /tmp/processedTrain/Chrysler Sebring Convertible 2010/05767.jpg
# Processing image 5768 of 8144
# Saved /tmp/processedTrain/Dodge Charger SRT-8 2009/05768.jpg
# Processing image 5769 of 8144
# Saved /tmp/processedTrain/Bentley Continental GT Coupe 2012/05769.jpg
# Processing image 5770 of 8144
# Saved /tmp/processedTrain/Scion xD Hatchback 2012/05770.jpg
# Processing image 5771 of 8144
# Saved /tmp/processedTrain/GMC Terrain SUV 2012/05771.jpg
# Processing image 5772 of 8144
# Saved /tmp/processedTrain/BMW X3 SUV 2012/05772.jpg
# Processing image 5773 of 8144
# Saved /tmp/processedTrain/Hyundai Veloster Hatchback 2012/05773.jpg
# Processing image 5774 of 8144
# Saved /tmp/processedTrain/Rolls-Royce Ghost Sedan 2012/05774.jpg
# Processing image 5775 of 8144
# Saved /tmp/processedTrain/Geo Metro Convertible 1993/05775.jpg
# Processing image 5776 of 8144
# Saved /tmp/processedTrain/Jeep Patriot SUV 2012/05776.jpg
# Processing image 5777 of 8144
# Saved /tmp/processedTrain/Toyota Corolla Sedan 2012/05777.jpg
# Processing image 5778 of 8144
# Saved /tmp/processedTrain/Mazda Tribute SUV 2011/05778.jpg
# Processing image 5779 of 8144
# Saved /tmp/processedTrain/Bentley Continental Flying Spur Sedan 2007/05779.jpg
# Processing image 5780 of 8144
# Saved /tmp/processedTrain/Jeep Compass SUV 2012/05780.jpg
# Processing image 5781 of 8144
# Saved /tmp/processedTrain/Chevrolet Malibu Sedan 2007/05781.jpg
# Processing image 5782 of 8144
# Saved /tmp/processedTrain/FIAT 500 Convertible 2012/05782.jpg
# Processing image 5783 of 8144
# Saved /tmp/processedTrain/Ford Edge SUV 2012/05783.jpg
# Processing image 5784 of 8144
# Saved /tmp/processedTrain/Dodge Journey SUV 2012/05784.jpg
# Processing image 5785 of 8144
# Saved /tmp/processedTrain/Nissan NV Passenger Van 2012/05785.jpg
# Processing image 5786 of 8144
# Saved /tmp/processedTrain/Chevrolet HHR SS 2010/05786.jpg
# Processing image 5787 of 8144
# Saved /tmp/processedTrain/Audi 100 Wagon 1994/05787.jpg
# Processing image 5788 of 8144
# Saved /tmp/processedTrain/Chevrolet Monte Carlo Coupe 2007/05788.jpg
# Processing image 5789 of 8144
# Saved /tmp/processedTrain/Rolls-Royce Phantom Drophead Coupe Convertible 2012/05789.jpg
# Processing image 5790 of 8144
# Saved /tmp/processedTrain/Mazda Tribute SUV 2011/05790.jpg
# Processing image 5791 of 8144
# Saved /tmp/processedTrain/Dodge Journey SUV 2012/05791.jpg
# Processing image 5792 of 8144
# Saved /tmp/processedTrain/Dodge Challenger SRT8 2011/05792.jpg
# Processing image 5793 of 8144
# Saved /tmp/processedTrain/Lincoln Town Car Sedan 2011/05793.jpg
# Processing image 5794 of 8144
# Saved /tmp/processedTrain/BMW 1 Series Coupe 2012/05794.jpg
# Processing image 5795 of 8144
# Saved /tmp/processedTrain/Tesla Model S Sedan 2012/05795.jpg
# Processing image 5796 of 8144
# Saved /tmp/processedTrain/Land Rover LR2 SUV 2012/05796.jpg
# Processing image 5797 of 8144
# Saved /tmp/processedTrain/McLaren MP4-12C Coupe 2012/05797.jpg
# Processing image 5798 of 8144
# Saved /tmp/processedTrain/Hyundai Elantra Touring Hatchback 2012/05798.jpg
# Processing image 5799 of 8144
# Saved /tmp/processedTrain/Dodge Durango SUV 2012/05799.jpg
# Processing image 5800 of 8144
# Saved /tmp/processedTrain/Bugatti Veyron 16.4 Convertible 2009/05800.jpg
# Processing image 5801 of 8144
# Saved /tmp/processedTrain/GMC Terrain SUV 2012/05801.jpg
# Processing image 5802 of 8144
# Saved /tmp/processedTrain/Audi V8 Sedan 1994/05802.jpg
# Processing image 5803 of 8144
# Saved /tmp/processedTrain/Bentley Mulsanne Sedan 2011/05803.jpg
# Processing image 5804 of 8144
# Saved /tmp/processedTrain/AM General Hummer SUV 2000/05804.jpg
# Processing image 5805 of 8144
# Saved /tmp/processedTrain/Ferrari California Convertible 2012/05805.jpg
# Processing image 5806 of 8144
# Saved /tmp/processedTrain/GMC Savana Van 2012/05806.jpg
# Processing image 5807 of 8144
# Saved /tmp/processedTrain/Mercedes-Benz 300-Class Convertible 1993/05807.jpg
# Processing image 5808 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Extended Cab 2012/05808.jpg
# Processing image 5809 of 8144
# Saved /tmp/processedTrain/Chevrolet Avalanche Crew Cab 2012/05809.jpg
# Processing image 5810 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Classic Extended Cab 2007/05810.jpg
# Processing image 5811 of 8144
# Saved /tmp/processedTrain/Chevrolet Camaro Convertible 2012/05811.jpg
# Processing image 5812 of 8144
# Saved /tmp/processedTrain/Hyundai Veracruz SUV 2012/05812.jpg
# Processing image 5813 of 8144
# Saved /tmp/processedTrain/Dodge Dakota Club Cab 2007/05813.jpg
# Processing image 5814 of 8144
# Saved /tmp/processedTrain/Buick Verano Sedan 2012/05814.jpg
# Processing image 5815 of 8144
# Saved /tmp/processedTrain/Dodge Charger Sedan 2012/05815.jpg
# Processing image 5816 of 8144
# Saved /tmp/processedTrain/Bugatti Veyron 16.4 Convertible 2009/05816.jpg
# Processing image 5817 of 8144
# Saved /tmp/processedTrain/Nissan NV Passenger Van 2012/05817.jpg
# Processing image 5818 of 8144
# Saved /tmp/processedTrain/Chevrolet Avalanche Crew Cab 2012/05818.jpg
# Processing image 5819 of 8144
# Saved /tmp/processedTrain/Hyundai Sonata Hybrid Sedan 2012/05819.jpg
# Processing image 5820 of 8144
# Saved /tmp/processedTrain/Cadillac CTS-V Sedan 2012/05820.jpg
# Processing image 5821 of 8144
# Saved /tmp/processedTrain/Aston Martin V8 Vantage Convertible 2012/05821.jpg
# Processing image 5822 of 8144
# Saved /tmp/processedTrain/Dodge Magnum Wagon 2008/05822.jpg
# Processing image 5823 of 8144
# Saved /tmp/processedTrain/Mazda Tribute SUV 2011/05823.jpg
# Processing image 5824 of 8144
# Saved /tmp/processedTrain/Audi S4 Sedan 2012/05824.jpg
# Processing image 5825 of 8144
# Saved /tmp/processedTrain/Dodge Journey SUV 2012/05825.jpg
# Processing image 5826 of 8144
# Saved /tmp/processedTrain/Dodge Dakota Club Cab 2007/05826.jpg
# Processing image 5827 of 8144
# Saved /tmp/processedTrain/Hyundai Azera Sedan 2012/05827.jpg
# Processing image 5828 of 8144
# Saved /tmp/processedTrain/Honda Accord Sedan 2012/05828.jpg
# Processing image 5829 of 8144
# Saved /tmp/processedTrain/Infiniti QX56 SUV 2011/05829.jpg
# Processing image 5830 of 8144
# Saved /tmp/processedTrain/BMW M6 Convertible 2010/05830.jpg
# Processing image 5831 of 8144
# Saved /tmp/processedTrain/Dodge Ram Pickup 3500 Quad Cab 2009/05831.jpg
# Processing image 5832 of 8144
# Saved /tmp/processedTrain/Chevrolet TrailBlazer SS 2009/05832.jpg
# Processing image 5833 of 8144
# Saved /tmp/processedTrain/Chevrolet Impala Sedan 2007/05833.jpg
# Processing image 5834 of 8144
# Saved /tmp/processedTrain/BMW M5 Sedan 2010/05834.jpg
# Processing image 5835 of 8144
# Saved /tmp/processedTrain/Cadillac Escalade EXT Crew Cab 2007/05835.jpg
# Processing image 5836 of 8144
# Saved /tmp/processedTrain/Mitsubishi Lancer Sedan 2012/05836.jpg
# Processing image 5837 of 8144
# Saved /tmp/processedTrain/Chevrolet Camaro Convertible 2012/05837.jpg
# Processing image 5838 of 8144
# Saved /tmp/processedTrain/Toyota Camry Sedan 2012/05838.jpg
# Processing image 5839 of 8144
# Saved /tmp/processedTrain/BMW ActiveHybrid 5 Sedan 2012/05839.jpg
# Processing image 5840 of 8144
# Saved /tmp/processedTrain/Buick Enclave SUV 2012/05840.jpg
# Processing image 5841 of 8144
# Saved /tmp/processedTrain/Volvo XC90 SUV 2007/05841.jpg
# Processing image 5842 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Extended Cab 2012/05842.jpg
# Processing image 5843 of 8144
# Saved /tmp/processedTrain/HUMMER H3T Crew Cab 2010/05843.jpg
# Processing image 5844 of 8144
# Saved /tmp/processedTrain/Chevrolet Sonic Sedan 2012/05844.jpg
# Processing image 5845 of 8144
# Saved /tmp/processedTrain/Mercedes-Benz Sprinter Van 2012/05845.jpg
# Processing image 5846 of 8144
# Saved /tmp/processedTrain/Ford GT Coupe 2006/05846.jpg
# Processing image 5847 of 8144
# Saved /tmp/processedTrain/Dodge Durango SUV 2012/05847.jpg
# Processing image 5848 of 8144
# Saved /tmp/processedTrain/Volkswagen Golf Hatchback 2012/05848.jpg
# Processing image 5849 of 8144
# Saved /tmp/processedTrain/Nissan Juke Hatchback 2012/05849.jpg
# Processing image 5850 of 8144
# Saved /tmp/processedTrain/Jeep Liberty SUV 2012/05850.jpg
# Processing image 5851 of 8144
# Saved /tmp/processedTrain/Dodge Durango SUV 2007/05851.jpg
# Processing image 5852 of 8144
# Saved /tmp/processedTrain/BMW Z4 Convertible 2012/05852.jpg
# Processing image 5853 of 8144
# Saved /tmp/processedTrain/Honda Accord Sedan 2012/05853.jpg
# Processing image 5854 of 8144
# Saved /tmp/processedTrain/Suzuki SX4 Hatchback 2012/05854.jpg
# Processing image 5855 of 8144
# Saved /tmp/processedTrain/Rolls-Royce Ghost Sedan 2012/05855.jpg
# Processing image 5856 of 8144
# Saved /tmp/processedTrain/Suzuki Kizashi Sedan 2012/05856.jpg
# Processing image 5857 of 8144
# Saved /tmp/processedTrain/Audi TTS Coupe 2012/05857.jpg
# Processing image 5858 of 8144
# Saved /tmp/processedTrain/Hyundai Veloster Hatchback 2012/05858.jpg
# Processing image 5859 of 8144
# Saved /tmp/processedTrain/Ford Edge SUV 2012/05859.jpg
# Processing image 5860 of 8144
# Saved /tmp/processedTrain/Chrysler Aspen SUV 2009/05860.jpg
# Processing image 5861 of 8144
# Saved /tmp/processedTrain/BMW Z4 Convertible 2012/05861.jpg
# Processing image 5862 of 8144
# Saved /tmp/processedTrain/Ford E-Series Wagon Van 2012/05862.jpg
# Processing image 5863 of 8144
# Saved /tmp/processedTrain/Honda Odyssey Minivan 2012/05863.jpg
# Processing image 5864 of 8144
# Saved /tmp/processedTrain/Honda Odyssey Minivan 2012/05864.jpg
# Processing image 5865 of 8144
# Saved /tmp/processedTrain/Bentley Arnage Sedan 2009/05865.jpg
# Processing image 5866 of 8144
# Saved /tmp/processedTrain/Chrysler Crossfire Convertible 2008/05866.jpg
# Processing image 5867 of 8144
# Saved /tmp/processedTrain/BMW M3 Coupe 2012/05867.jpg
# Processing image 5868 of 8144
# Saved /tmp/processedTrain/BMW Z4 Convertible 2012/05868.jpg
# Processing image 5869 of 8144
# Saved /tmp/processedTrain/Audi 100 Wagon 1994/05869.jpg
# Processing image 5870 of 8144
# Saved /tmp/processedTrain/Bentley Continental GT Coupe 2007/05870.jpg
# Processing image 5871 of 8144
# Saved /tmp/processedTrain/Dodge Caravan Minivan 1997/05871.jpg
# Processing image 5872 of 8144
# Saved /tmp/processedTrain/Suzuki SX4 Sedan 2012/05872.jpg
# Processing image 5873 of 8144
# Saved /tmp/processedTrain/Bentley Continental Supersports Conv. Convertible 2012/05873.jpg
# Processing image 5874 of 8144
# Saved /tmp/processedTrain/Ferrari 458 Italia Coupe 2012/05874.jpg
# Processing image 5875 of 8144
# Saved /tmp/processedTrain/Bentley Arnage Sedan 2009/05875.jpg
# Processing image 5876 of 8144
# Saved /tmp/processedTrain/Lamborghini Diablo Coupe 2001/05876.jpg
# Processing image 5877 of 8144
# Saved /tmp/processedTrain/BMW X6 SUV 2012/05877.jpg
# Processing image 5878 of 8144
# Saved /tmp/processedTrain/BMW 1 Series Convertible 2012/05878.jpg
# Processing image 5879 of 8144
# Saved /tmp/processedTrain/Dodge Charger SRT-8 2009/05879.jpg
# Processing image 5880 of 8144
# Saved /tmp/processedTrain/Land Rover LR2 SUV 2012/05880.jpg
# Processing image 5881 of 8144
# Saved /tmp/processedTrain/Cadillac SRX SUV 2012/05881.jpg
# Processing image 5882 of 8144
# Saved /tmp/processedTrain/Chevrolet Monte Carlo Coupe 2007/05882.jpg
# Processing image 5883 of 8144
# Saved /tmp/processedTrain/GMC Terrain SUV 2012/05883.jpg
# Processing image 5884 of 8144
# Saved /tmp/processedTrain/Ferrari 458 Italia Coupe 2012/05884.jpg
# Processing image 5885 of 8144
# Saved /tmp/processedTrain/Chrysler Crossfire Convertible 2008/05885.jpg
# Processing image 5886 of 8144
# Saved /tmp/processedTrain/Audi TT RS Coupe 2012/05886.jpg
# Processing image 5887 of 8144
# Saved /tmp/processedTrain/Audi S4 Sedan 2007/05887.jpg
# Processing image 5888 of 8144
# Saved /tmp/processedTrain/Dodge Caravan Minivan 1997/05888.jpg
# Processing image 5889 of 8144
# Saved /tmp/processedTrain/BMW 3 Series Sedan 2012/05889.jpg
# Processing image 5890 of 8144
# Saved /tmp/processedTrain/Volvo C30 Hatchback 2012/05890.jpg
# Processing image 5891 of 8144
# Saved /tmp/processedTrain/HUMMER H2 SUT Crew Cab 2009/05891.jpg
# Processing image 5892 of 8144
# Saved /tmp/processedTrain/BMW 6 Series Convertible 2007/05892.jpg
# Processing image 5893 of 8144
# Saved /tmp/processedTrain/Bentley Continental GT Coupe 2007/05893.jpg
# Processing image 5894 of 8144
# Saved /tmp/processedTrain/Toyota 4Runner SUV 2012/05894.jpg
# Processing image 5895 of 8144
# Saved /tmp/processedTrain/Honda Odyssey Minivan 2012/05895.jpg
# Processing image 5896 of 8144
# Saved /tmp/processedTrain/Eagle Talon Hatchback 1998/05896.jpg
# Processing image 5897 of 8144
# Saved /tmp/processedTrain/BMW X3 SUV 2012/05897.jpg
# Processing image 5898 of 8144
# Saved /tmp/processedTrain/Hyundai Azera Sedan 2012/05898.jpg
# Processing image 5899 of 8144
# Saved /tmp/processedTrain/HUMMER H3T Crew Cab 2010/05899.jpg
# Processing image 5900 of 8144
# Saved /tmp/processedTrain/Jeep Liberty SUV 2012/05900.jpg
# Processing image 5901 of 8144
# Saved /tmp/processedTrain/GMC Acadia SUV 2012/05901.jpg
# Processing image 5902 of 8144
# Saved /tmp/processedTrain/Audi TT RS Coupe 2012/05902.jpg
# Processing image 5903 of 8144
# Saved /tmp/processedTrain/Volkswagen Golf Hatchback 2012/05903.jpg
# Processing image 5904 of 8144
# Saved /tmp/processedTrain/Rolls-Royce Phantom Drophead Coupe Convertible 2012/05904.jpg
# Processing image 5905 of 8144
# Saved /tmp/processedTrain/GMC Savana Van 2012/05905.jpg
# Processing image 5906 of 8144
# Saved /tmp/processedTrain/Ford Fiesta Sedan 2012/05906.jpg
# Processing image 5907 of 8144
# Saved /tmp/processedTrain/Porsche Panamera Sedan 2012/05907.jpg
# Processing image 5908 of 8144
# Saved /tmp/processedTrain/Audi S4 Sedan 2007/05908.jpg
# Processing image 5909 of 8144
# Saved /tmp/processedTrain/Aston Martin V8 Vantage Coupe 2012/05909.jpg
# Processing image 5910 of 8144
# Saved /tmp/processedTrain/Ford F-450 Super Duty Crew Cab 2012/05910.jpg
# Processing image 5911 of 8144
# Saved /tmp/processedTrain/Chrysler Town and Country Minivan 2012/05911.jpg
# Processing image 5912 of 8144
# Saved /tmp/processedTrain/Buick Verano Sedan 2012/05912.jpg
# Processing image 5913 of 8144
# Saved /tmp/processedTrain/GMC Yukon Hybrid SUV 2012/05913.jpg
# Processing image 5914 of 8144
# Saved /tmp/processedTrain/Rolls-Royce Phantom Sedan 2012/05914.jpg
# Processing image 5915 of 8144
# Saved /tmp/processedTrain/Hyundai Genesis Sedan 2012/05915.jpg
# Processing image 5916 of 8144
# Saved /tmp/processedTrain/Acura Integra Type R 2001/05916.jpg
# Processing image 5917 of 8144
# Saved /tmp/processedTrain/Land Rover LR2 SUV 2012/05917.jpg
# Processing image 5918 of 8144
# Saved /tmp/processedTrain/Acura TL Sedan 2012/05918.jpg
# Processing image 5919 of 8144
# Saved /tmp/processedTrain/Ford F-450 Super Duty Crew Cab 2012/05919.jpg
# Processing image 5920 of 8144
# Saved /tmp/processedTrain/Hyundai Sonata Sedan 2012/05920.jpg
# Processing image 5921 of 8144
# Saved /tmp/processedTrain/AM General Hummer SUV 2000/05921.jpg
# Processing image 5922 of 8144
# Saved /tmp/processedTrain/Fisker Karma Sedan 2012/05922.jpg
# Processing image 5923 of 8144
# Saved /tmp/processedTrain/Bentley Continental Flying Spur Sedan 2007/05923.jpg
# Processing image 5924 of 8144
# Saved /tmp/processedTrain/Audi V8 Sedan 1994/05924.jpg
# Processing image 5925 of 8144
# Saved /tmp/processedTrain/GMC Canyon Extended Cab 2012/05925.jpg
# Processing image 5926 of 8144
# Saved /tmp/processedTrain/Lincoln Town Car Sedan 2011/05926.jpg
# Processing image 5927 of 8144
# Saved /tmp/processedTrain/Dodge Journey SUV 2012/05927.jpg
# Processing image 5928 of 8144
# Saved /tmp/processedTrain/Bentley Mulsanne Sedan 2011/05928.jpg
# Processing image 5929 of 8144
# Saved /tmp/processedTrain/Honda Odyssey Minivan 2012/05929.jpg
# Processing image 5930 of 8144
# Saved /tmp/processedTrain/Acura RL Sedan 2012/05930.jpg
# Processing image 5931 of 8144
# Saved /tmp/processedTrain/Volkswagen Golf Hatchback 2012/05931.jpg
# Processing image 5932 of 8144
# Saved /tmp/processedTrain/Chevrolet Corvette Convertible 2012/05932.jpg
# Processing image 5933 of 8144
# Saved /tmp/processedTrain/Ford E-Series Wagon Van 2012/05933.jpg
# Processing image 5934 of 8144
# Saved /tmp/processedTrain/Fisker Karma Sedan 2012/05934.jpg
# Processing image 5935 of 8144
# Saved /tmp/processedTrain/Honda Odyssey Minivan 2012/05935.jpg
# Processing image 5936 of 8144
# Saved /tmp/processedTrain/Chevrolet Traverse SUV 2012/05936.jpg
# Processing image 5937 of 8144
# Saved /tmp/processedTrain/Dodge Sprinter Cargo Van 2009/05937.jpg
# Processing image 5938 of 8144
# Saved /tmp/processedTrain/Ferrari 458 Italia Convertible 2012/05938.jpg
# Processing image 5939 of 8144
# Saved /tmp/processedTrain/Nissan Juke Hatchback 2012/05939.jpg
# Processing image 5940 of 8144
# Saved /tmp/processedTrain/Hyundai Genesis Sedan 2012/05940.jpg
# Processing image 5941 of 8144
# Saved /tmp/processedTrain/Volkswagen Golf Hatchback 2012/05941.jpg
# Processing image 5942 of 8144
# Saved /tmp/processedTrain/Chevrolet TrailBlazer SS 2009/05942.jpg
# Processing image 5943 of 8144
# Saved /tmp/processedTrain/GMC Acadia SUV 2012/05943.jpg
# Processing image 5944 of 8144
# Saved /tmp/processedTrain/Cadillac CTS-V Sedan 2012/05944.jpg
# Processing image 5945 of 8144
# Saved /tmp/processedTrain/Chevrolet Sonic Sedan 2012/05945.jpg
# Processing image 5946 of 8144
# Saved /tmp/processedTrain/Bentley Continental Flying Spur Sedan 2007/05946.jpg
# Processing image 5947 of 8144
# Saved /tmp/processedTrain/BMW 1 Series Coupe 2012/05947.jpg
# Processing image 5948 of 8144
# Saved /tmp/processedTrain/Buick Rainier SUV 2007/05948.jpg
# Processing image 5949 of 8144
# Saved /tmp/processedTrain/Chevrolet Monte Carlo Coupe 2007/05949.jpg
# Processing image 5950 of 8144
# Saved /tmp/processedTrain/Jaguar XK XKR 2012/05950.jpg
# Processing image 5951 of 8144
# Saved /tmp/processedTrain/Suzuki SX4 Hatchback 2012/05951.jpg
# Processing image 5952 of 8144
# Saved /tmp/processedTrain/GMC Terrain SUV 2012/05952.jpg
# Processing image 5953 of 8144
# Saved /tmp/processedTrain/Dodge Charger Sedan 2012/05953.jpg
# Processing image 5954 of 8144
# Saved /tmp/processedTrain/Spyker C8 Coupe 2009/05954.jpg
# Processing image 5955 of 8144
# Saved /tmp/processedTrain/Hyundai Accent Sedan 2012/05955.jpg
# Processing image 5956 of 8144
# Saved /tmp/processedTrain/Toyota Corolla Sedan 2012/05956.jpg
# Processing image 5957 of 8144
# Saved /tmp/processedTrain/Ferrari 458 Italia Coupe 2012/05957.jpg
# Processing image 5958 of 8144
# Saved /tmp/processedTrain/Honda Accord Sedan 2012/05958.jpg
# Processing image 5959 of 8144
# Saved /tmp/processedTrain/Honda Odyssey Minivan 2012/05959.jpg
# Processing image 5960 of 8144
# Saved /tmp/processedTrain/Dodge Dakota Crew Cab 2010/05960.jpg
# Processing image 5961 of 8144
# Saved /tmp/processedTrain/Dodge Caliber Wagon 2012/05961.jpg
# Processing image 5962 of 8144
# Saved /tmp/processedTrain/Mercedes-Benz C-Class Sedan 2012/05962.jpg
# Processing image 5963 of 8144
# Saved /tmp/processedTrain/Nissan Juke Hatchback 2012/05963.jpg
# Processing image 5964 of 8144
# Saved /tmp/processedTrain/Audi S5 Convertible 2012/05964.jpg
# Processing image 5965 of 8144
# Saved /tmp/processedTrain/Audi S6 Sedan 2011/05965.jpg
# Processing image 5966 of 8144
# Saved /tmp/processedTrain/Infiniti QX56 SUV 2011/05966.jpg
# Processing image 5967 of 8144
# Saved /tmp/processedTrain/Acura TL Sedan 2012/05967.jpg
# Processing image 5968 of 8144
# Saved /tmp/processedTrain/Audi 100 Sedan 1994/05968.jpg
# Processing image 5969 of 8144
# Saved /tmp/processedTrain/Chevrolet Corvette Ron Fellows Edition Z06 2007/05969.jpg
# Processing image 5970 of 8144
# Saved /tmp/processedTrain/Ford Focus Sedan 2007/05970.jpg
# Processing image 5971 of 8144
# Saved /tmp/processedTrain/Bentley Mulsanne Sedan 2011/05971.jpg
# Processing image 5972 of 8144
# Saved /tmp/processedTrain/Audi S4 Sedan 2012/05972.jpg
# Processing image 5973 of 8144
# Saved /tmp/processedTrain/Lamborghini Aventador Coupe 2012/05973.jpg
# Processing image 5974 of 8144
# Saved /tmp/processedTrain/Toyota Sequoia SUV 2012/05974.jpg
# Processing image 5975 of 8144
# Saved /tmp/processedTrain/Land Rover LR2 SUV 2012/05975.jpg
# Processing image 5976 of 8144
# Saved /tmp/processedTrain/Geo Metro Convertible 1993/05976.jpg
# Processing image 5977 of 8144
# Saved /tmp/processedTrain/Volkswagen Beetle Hatchback 2012/05977.jpg
# Processing image 5978 of 8144
# Saved /tmp/processedTrain/Dodge Magnum Wagon 2008/05978.jpg
# Processing image 5979 of 8144
# Saved /tmp/processedTrain/Acura TL Type-S 2008/05979.jpg
# Processing image 5980 of 8144
# Saved /tmp/processedTrain/Ford Fiesta Sedan 2012/05980.jpg
# Processing image 5981 of 8144
# Saved /tmp/processedTrain/Bentley Continental Flying Spur Sedan 2007/05981.jpg
# Processing image 5982 of 8144
# Saved /tmp/processedTrain/Tesla Model S Sedan 2012/05982.jpg
# Processing image 5983 of 8144
# Saved /tmp/processedTrain/Chevrolet Camaro Convertible 2012/05983.jpg
# Processing image 5984 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Regular Cab 2012/05984.jpg
# Processing image 5985 of 8144
# Saved /tmp/processedTrain/BMW 1 Series Coupe 2012/05985.jpg
# Processing image 5986 of 8144
# Saved /tmp/processedTrain/Audi S6 Sedan 2011/05986.jpg
# Processing image 5987 of 8144
# Saved /tmp/processedTrain/Ford E-Series Wagon Van 2012/05987.jpg
# Processing image 5988 of 8144
# Saved /tmp/processedTrain/Hyundai Tucson SUV 2012/05988.jpg
# Processing image 5989 of 8144
# Saved /tmp/processedTrain/Dodge Dakota Crew Cab 2010/05989.jpg
# Processing image 5990 of 8144
# Saved /tmp/processedTrain/Lamborghini Aventador Coupe 2012/05990.jpg
# Processing image 5991 of 8144
# Saved /tmp/processedTrain/Chevrolet TrailBlazer SS 2009/05991.jpg
# Processing image 5992 of 8144
# Saved /tmp/processedTrain/Buick Rainier SUV 2007/05992.jpg
# Processing image 5993 of 8144
# Saved /tmp/processedTrain/Chevrolet Sonic Sedan 2012/05993.jpg
# Processing image 5994 of 8144
# Saved /tmp/processedTrain/Jeep Patriot SUV 2012/05994.jpg
# Processing image 5995 of 8144
# Saved /tmp/processedTrain/Mercedes-Benz 300-Class Convertible 1993/05995.jpg
# Processing image 5996 of 8144
# Saved /tmp/processedTrain/Chrysler Sebring Convertible 2010/05996.jpg
# Processing image 5997 of 8144
# Saved /tmp/processedTrain/Buick Enclave SUV 2012/05997.jpg
# Processing image 5998 of 8144
# Saved /tmp/processedTrain/Nissan Juke Hatchback 2012/05998.jpg
# Processing image 5999 of 8144
# Saved /tmp/processedTrain/Mazda Tribute SUV 2011/05999.jpg
# Processing image 6000 of 8144
# Saved /tmp/processedTrain/Dodge Ram Pickup 3500 Quad Cab 2009/06000.jpg
# Processing image 6001 of 8144
# Saved /tmp/processedTrain/Rolls-Royce Ghost Sedan 2012/06001.jpg
# Processing image 6002 of 8144
# Saved /tmp/processedTrain/Aston Martin V8 Vantage Convertible 2012/06002.jpg
# Processing image 6003 of 8144
# Saved /tmp/processedTrain/Ferrari 458 Italia Convertible 2012/06003.jpg
# Processing image 6004 of 8144
# Saved /tmp/processedTrain/smart fortwo Convertible 2012/06004.jpg
# Processing image 6005 of 8144
# Saved /tmp/processedTrain/Bentley Continental GT Coupe 2012/06005.jpg
# Processing image 6006 of 8144
# Saved /tmp/processedTrain/Bentley Continental Supersports Conv. Convertible 2012/06006.jpg
# Processing image 6007 of 8144
# Saved /tmp/processedTrain/McLaren MP4-12C Coupe 2012/06007.jpg
# Processing image 6008 of 8144
# Saved /tmp/processedTrain/Audi RS 4 Convertible 2008/06008.jpg
# Processing image 6009 of 8144
# Saved /tmp/processedTrain/McLaren MP4-12C Coupe 2012/06009.jpg
# Processing image 6010 of 8144
# Saved /tmp/processedTrain/Chrysler Sebring Convertible 2010/06010.jpg
# Processing image 6011 of 8144
# Saved /tmp/processedTrain/Audi TT Hatchback 2011/06011.jpg
# Processing image 6012 of 8144
# Saved /tmp/processedTrain/GMC Yukon Hybrid SUV 2012/06012.jpg
# Processing image 6013 of 8144
# Saved /tmp/processedTrain/Volvo XC90 SUV 2007/06013.jpg
# Processing image 6014 of 8144
# Saved /tmp/processedTrain/FIAT 500 Convertible 2012/06014.jpg
# Processing image 6015 of 8144
# Saved /tmp/processedTrain/Lincoln Town Car Sedan 2011/06015.jpg
# Processing image 6016 of 8144
# Saved /tmp/processedTrain/Toyota Camry Sedan 2012/06016.jpg
# Processing image 6017 of 8144
# Saved /tmp/processedTrain/Fisker Karma Sedan 2012/06017.jpg
# Processing image 6018 of 8144
# Saved /tmp/processedTrain/Dodge Magnum Wagon 2008/06018.jpg
# Processing image 6019 of 8144
# Saved /tmp/processedTrain/Dodge Dakota Crew Cab 2010/06019.jpg
# Processing image 6020 of 8144
# Saved /tmp/processedTrain/Audi RS 4 Convertible 2008/06020.jpg
# Processing image 6021 of 8144
# Saved /tmp/processedTrain/Jaguar XK XKR 2012/06021.jpg
# Processing image 6022 of 8144
# Saved /tmp/processedTrain/Dodge Challenger SRT8 2011/06022.jpg
# Processing image 6023 of 8144
# Saved /tmp/processedTrain/Toyota Sequoia SUV 2012/06023.jpg
# Processing image 6024 of 8144
# Saved /tmp/processedTrain/Aston Martin V8 Vantage Convertible 2012/06024.jpg
# Processing image 6025 of 8144
# Saved /tmp/processedTrain/Chrysler Town and Country Minivan 2012/06025.jpg
# Processing image 6026 of 8144
# Saved /tmp/processedTrain/Chevrolet Camaro Convertible 2012/06026.jpg
# Processing image 6027 of 8144
# Saved /tmp/processedTrain/BMW X5 SUV 2007/06027.jpg
# Processing image 6028 of 8144
# Saved /tmp/processedTrain/Bentley Continental Flying Spur Sedan 2007/06028.jpg
# Processing image 6029 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Classic Extended Cab 2007/06029.jpg
# Processing image 6030 of 8144
# Saved /tmp/processedTrain/BMW 3 Series Wagon 2012/06030.jpg
# Processing image 6031 of 8144
# Saved /tmp/processedTrain/Ferrari FF Coupe 2012/06031.jpg
# Processing image 6032 of 8144
# Saved /tmp/processedTrain/Chevrolet Malibu Hybrid Sedan 2010/06032.jpg
# Processing image 6033 of 8144
# Saved /tmp/processedTrain/Chevrolet Malibu Sedan 2007/06033.jpg
# Processing image 6034 of 8144
# Saved /tmp/processedTrain/Ford GT Coupe 2006/06034.jpg
# Processing image 6035 of 8144
# Saved /tmp/processedTrain/Bentley Continental Supersports Conv. Convertible 2012/06035.jpg
# Processing image 6036 of 8144
# Saved /tmp/processedTrain/Ford F-150 Regular Cab 2007/06036.jpg
# Processing image 6037 of 8144
# Saved /tmp/processedTrain/Audi V8 Sedan 1994/06037.jpg
# Processing image 6038 of 8144
# Saved /tmp/processedTrain/McLaren MP4-12C Coupe 2012/06038.jpg
# Processing image 6039 of 8144
# Saved /tmp/processedTrain/GMC Yukon Hybrid SUV 2012/06039.jpg
# Processing image 6040 of 8144
# Saved /tmp/processedTrain/BMW M5 Sedan 2010/06040.jpg
# Processing image 6041 of 8144
# Saved /tmp/processedTrain/Honda Odyssey Minivan 2007/06041.jpg
# Processing image 6042 of 8144
# Saved /tmp/processedTrain/Land Rover Range Rover SUV 2012/06042.jpg
# Processing image 6043 of 8144
# Saved /tmp/processedTrain/Hyundai Veloster Hatchback 2012/06043.jpg
# Processing image 6044 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Extended Cab 2012/06044.jpg
# Processing image 6045 of 8144
# Saved /tmp/processedTrain/Plymouth Neon Coupe 1999/06045.jpg
# Processing image 6046 of 8144
# Saved /tmp/processedTrain/MINI Cooper Roadster Convertible 2012/06046.jpg
# Processing image 6047 of 8144
# Saved /tmp/processedTrain/Mercedes-Benz S-Class Sedan 2012/06047.jpg
# Processing image 6048 of 8144
# Saved /tmp/processedTrain/Chevrolet Corvette Ron Fellows Edition Z06 2007/06048.jpg
# Processing image 6049 of 8144
# Saved /tmp/processedTrain/Buick Enclave SUV 2012/06049.jpg
# Processing image 6050 of 8144
# Saved /tmp/processedTrain/Chevrolet TrailBlazer SS 2009/06050.jpg
# Processing image 6051 of 8144
# Saved /tmp/processedTrain/BMW Z4 Convertible 2012/06051.jpg
# Processing image 6052 of 8144
# Saved /tmp/processedTrain/AM General Hummer SUV 2000/06052.jpg
# Processing image 6053 of 8144
# Saved /tmp/processedTrain/GMC Savana Van 2012/06053.jpg
# Processing image 6054 of 8144
# Saved /tmp/processedTrain/Ford Freestar Minivan 2007/06054.jpg
# Processing image 6055 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Regular Cab 2012/06055.jpg
# Processing image 6056 of 8144
# Saved /tmp/processedTrain/Hyundai Elantra Touring Hatchback 2012/06056.jpg
# Processing image 6057 of 8144
# Saved /tmp/processedTrain/Ford F-150 Regular Cab 2007/06057.jpg
# Processing image 6058 of 8144
# Saved /tmp/processedTrain/Tesla Model S Sedan 2012/06058.jpg
# Processing image 6059 of 8144
# Saved /tmp/processedTrain/Hyundai Veloster Hatchback 2012/06059.jpg
# Processing image 6060 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/06060.jpg
# Processing image 6061 of 8144
# Saved /tmp/processedTrain/Acura RL Sedan 2012/06061.jpg
# Processing image 6062 of 8144
# Saved /tmp/processedTrain/Dodge Journey SUV 2012/06062.jpg
# Processing image 6063 of 8144
# Saved /tmp/processedTrain/Hyundai Veloster Hatchback 2012/06063.jpg
# Processing image 6064 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 2500HD Regular Cab 2012/06064.jpg
# Processing image 6065 of 8144
# Saved /tmp/processedTrain/Hyundai Sonata Sedan 2012/06065.jpg
# Processing image 6066 of 8144
# Saved /tmp/processedTrain/Chevrolet TrailBlazer SS 2009/06066.jpg
# Processing image 6067 of 8144
# Saved /tmp/processedTrain/Audi R8 Coupe 2012/06067.jpg
# Processing image 6068 of 8144
# Saved /tmp/processedTrain/Volvo XC90 SUV 2007/06068.jpg
# Processing image 6069 of 8144
# Saved /tmp/processedTrain/Land Rover Range Rover SUV 2012/06069.jpg
# Processing image 6070 of 8144
# Saved /tmp/processedTrain/Hyundai Elantra Touring Hatchback 2012/06070.jpg
# Processing image 6071 of 8144
# Saved /tmp/processedTrain/Audi TT Hatchback 2011/06071.jpg
# Processing image 6072 of 8144
# Saved /tmp/processedTrain/Bentley Continental GT Coupe 2012/06072.jpg
# Processing image 6073 of 8144
# Saved /tmp/processedTrain/Dodge Journey SUV 2012/06073.jpg
# Processing image 6074 of 8144
# Saved /tmp/processedTrain/Ford GT Coupe 2006/06074.jpg
# Processing image 6075 of 8144
# Saved /tmp/processedTrain/BMW X3 SUV 2012/06075.jpg
# Processing image 6076 of 8144
# Saved /tmp/processedTrain/Bentley Continental Flying Spur Sedan 2007/06076.jpg
# Processing image 6077 of 8144
# Saved /tmp/processedTrain/Jeep Grand Cherokee SUV 2012/06077.jpg
# Processing image 6078 of 8144
# Saved /tmp/processedTrain/BMW 1 Series Convertible 2012/06078.jpg
# Processing image 6079 of 8144
# Saved /tmp/processedTrain/Suzuki Aerio Sedan 2007/06079.jpg
# Processing image 6080 of 8144
# Saved /tmp/processedTrain/BMW M3 Coupe 2012/06080.jpg
# Processing image 6081 of 8144
# Saved /tmp/processedTrain/Mercedes-Benz 300-Class Convertible 1993/06081.jpg
# Processing image 6082 of 8144
# Saved /tmp/processedTrain/Mercedes-Benz S-Class Sedan 2012/06082.jpg
# Processing image 6083 of 8144
# Saved /tmp/processedTrain/Eagle Talon Hatchback 1998/06083.jpg
# Processing image 6084 of 8144
# Saved /tmp/processedTrain/Chrysler PT Cruiser Convertible 2008/06084.jpg
# Processing image 6085 of 8144
# Saved /tmp/processedTrain/MINI Cooper Roadster Convertible 2012/06085.jpg
# Processing image 6086 of 8144
# Saved /tmp/processedTrain/Dodge Challenger SRT8 2011/06086.jpg
# Processing image 6087 of 8144
# Saved /tmp/processedTrain/Chevrolet Express Cargo Van 2007/06087.jpg
# Processing image 6088 of 8144
# Saved /tmp/processedTrain/Audi RS 4 Convertible 2008/06088.jpg
# Processing image 6089 of 8144
# Saved /tmp/processedTrain/BMW 1 Series Convertible 2012/06089.jpg
# Processing image 6090 of 8144
# Saved /tmp/processedTrain/Honda Accord Sedan 2012/06090.jpg
# Processing image 6091 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Regular Cab 2012/06091.jpg
# Processing image 6092 of 8144
# Saved /tmp/processedTrain/Nissan Leaf Hatchback 2012/06092.jpg
# Processing image 6093 of 8144
# Saved /tmp/processedTrain/Nissan 240SX Coupe 1998/06093.jpg
# Processing image 6094 of 8144
# Saved /tmp/processedTrain/Audi TT Hatchback 2011/06094.jpg
# Processing image 6095 of 8144
# Saved /tmp/processedTrain/Hyundai Sonata Hybrid Sedan 2012/06095.jpg
# Processing image 6096 of 8144
# Saved /tmp/processedTrain/Mercedes-Benz E-Class Sedan 2012/06096.jpg
# Processing image 6097 of 8144
# Saved /tmp/processedTrain/Dodge Caliber Wagon 2007/06097.jpg
# Processing image 6098 of 8144
# Saved /tmp/processedTrain/Ferrari 458 Italia Coupe 2012/06098.jpg
# Processing image 6099 of 8144
# Saved /tmp/processedTrain/Acura TL Type-S 2008/06099.jpg
# Processing image 6100 of 8144
# Saved /tmp/processedTrain/Jeep Grand Cherokee SUV 2012/06100.jpg
# Processing image 6101 of 8144
# Saved /tmp/processedTrain/Jeep Patriot SUV 2012/06101.jpg
# Processing image 6102 of 8144
# Saved /tmp/processedTrain/Hyundai Genesis Sedan 2012/06102.jpg
# Processing image 6103 of 8144
# Saved /tmp/processedTrain/Chrysler PT Cruiser Convertible 2008/06103.jpg
# Processing image 6104 of 8144
# Saved /tmp/processedTrain/Volkswagen Golf Hatchback 2012/06104.jpg
# Processing image 6105 of 8144
# Saved /tmp/processedTrain/Audi S5 Coupe 2012/06105.jpg
# Processing image 6106 of 8144
# Saved /tmp/processedTrain/Ford Freestar Minivan 2007/06106.jpg
# Processing image 6107 of 8144
# Saved /tmp/processedTrain/BMW ActiveHybrid 5 Sedan 2012/06107.jpg
# Processing image 6108 of 8144
# Saved /tmp/processedTrain/Chevrolet Express Van 2007/06108.jpg
# Processing image 6109 of 8144
# Saved /tmp/processedTrain/Honda Accord Coupe 2012/06109.jpg
# Processing image 6110 of 8144
# Saved /tmp/processedTrain/Bentley Mulsanne Sedan 2011/06110.jpg
# Processing image 6111 of 8144
# Saved /tmp/processedTrain/Volvo C30 Hatchback 2012/06111.jpg
# Processing image 6112 of 8144
# Saved /tmp/processedTrain/Honda Odyssey Minivan 2012/06112.jpg
# Processing image 6113 of 8144
# Saved /tmp/processedTrain/Suzuki Aerio Sedan 2007/06113.jpg
# Processing image 6114 of 8144
# Saved /tmp/processedTrain/Suzuki SX4 Sedan 2012/06114.jpg
# Processing image 6115 of 8144
# Saved /tmp/processedTrain/Hyundai Elantra Sedan 2007/06115.jpg
# Processing image 6116 of 8144
# Saved /tmp/processedTrain/Chevrolet Silverado 1500 Classic Extended Cab 2007/06116.jpg
# Processing image 6117 of 8144
# Saved /tmp/processedTrain/Hyundai Elantra Touring Hatchback 2012/06117.jpg
# Processing image 6118 of 8144
# Saved /tmp/processedTrain/HUMMER H3T Crew Cab 2010/06118.jpg
# Processing image 6119 of 8144
# Saved /tmp/processedTrain/Dodge Caravan Minivan 1997/06119.jpg
# Processing image 6120 of 8144
# Saved /tmp/processedTrain/Chevrolet Traverse SUV 2012/06120.jpg
# Processing image 6121 of 8144
# Saved /tmp/processedTrain/Dodge Magnum Wagon 2008/06121.jpg
# Processing image 6122 of 8144
# Saved /tmp/processedTrain/BMW M5 Sedan 2010/06122.jpg
# Processing image 6123 of 8144
# Saved /tmp/processedTrain/Suzuki SX4 Hatchback 2012/06123.jpg
# Processing image 6124 of 8144
# Saved /tmp/processedTrain/Buick Enclave SUV 2012/06124.jpg
# Processing image 6125 of 8144
# Saved /tmp/processedTrain/Chevrolet Express Cargo Van 2007/06125.jpg
# Processing image 6126 of 8144
# Saved /tmp/processedTrain/FIAT 500 Abarth 2012/06126.jpg
# Processing image 6127 of 8144
# Saved /tmp/processedTrain/Volvo 240 Sedan 1993/06127.jpg
# Processing image 6128 of 8144
# Saved /tmp/processedTrain/Bentley Arnage Sedan 2009/06128.jpg
# Processing image 6129 of 8144
# Saved /tmp/processedTrain/Chevrolet Cobalt SS 2010/06129.jpg
# Processing image 6130 of 8144
# Saved /tmp/processedTrain/Mercedes-Benz C-Class Sedan 2012/06130.jpg
# Processing image 6131 of 8144
# Saved /tmp/processedTrain/Ford Edge SUV 2012/06131.jpg
# Processing image 6132 of 8144
# Saved /tmp/processedTrain/Chrysler Crossfire Convertible 2008/06132.jpg
# Processing image 6133 of 8144
# Saved /tmp/processedTrain/Ford F-150 Regular Cab 2012/06133.jpg
# Processing image 6134 of 8144
# Saved /tmp/processedTrain/Dodge Sprinter Cargo Van 2009/06134.jpg
# Processing image 6135 of 8144
# Saved /tmp/processedTrain/Nissan 240SX Coupe 1998/06135.jpg
# Processing image 6136 of 8144
# Saved /tmp/processedTrain/Cadillac CTS-V Sedan 2012/06136.jpg
# Processing image 6137 of 8144
# Saved /tmp/processedTrain/Chrysler PT Cruiser Convertible 2008/06137.jpg
# Processing image 6138 of 8144
# Saved /tmp/processedTrain/Hyundai Sonata Hybrid Sedan 2012/06138.jpg
# Processing image 6139 of 8144
# Saved /tmp/processedTrain/Chevrolet Monte Carlo Coupe 2007/06139.jpg
# Processing image 6140 of 8144
# Saved /tmp/processedTrain/Chrysler 300 SRT-8 2010/06140.jpg
# Processing image 6141 of 8144
# Saved /tmp/processedTrain/Jeep Liberty SUV 2012/06141.jpg
# Processing image 6142 of 8144
# Saved /tmp/processedTrain/Buick Rainier SUV 2007/06142.jpg
# Processing image 6143 of 8144
# Saved /tmp/processedTrain/Hyundai Sonata Hybrid Sedan 2012/06143.jpg
# Processing image 6144 of 8144
# Saved /tmp/processedTrain/Plymouth Neon Coupe 1999/06144.jpg
# Processing image 6145 of 8144
# Saved /tmp/processedTrain/Acura TL Type-S 2008/06145.jpg
# Processing image 6146 of 8144
# Saved /tmp/processedTrain/Chrysler Aspen SUV 2009/06146.jpg
# Processing image 6147 of 8144
# Saved /tmp/processedTrain/Chrysler Sebring Convertible 2010/06147.jpg
# Processing image 6148 of 8144
# Saved /tmp/processedTrain/Ford Mustang Convertible 2007/06148.jpg
# Processing image 6149 of 8144
# Saved /tmp/processedTrain/Tesla Model S Sedan 2012/06149.jpg
# Processing image 6150 of 8144
# Saved /tmp/processedTrain/Nissan NV Passenger Van 2012/06150.jpg
# Processing image 6151 of 8144
# Saved /tmp/processedTrain/Audi S6 Sedan 2011/06151.jpg
# Processing image 6152 of 8144
# Saved /tmp/processedTrain/Ford Expedition EL SUV 2009/06152.jpg
# Processing image 6153 of 8144
# Saved /tmp/processedTrain/HUMMER H2 SUT Crew Cab 2009/06153.jpg
# Processing image 6154 of 8144
# Saved /tmp/processedTrain/GMC Savana Van 2012/06154.jpg
# Processing image 6155 of 8144
# Saved /tmp/processedTrain/Bugatti Veyron 16.4 Coupe 2009/06155.jpg
# Processing image 6156 of 8144
# ...
# Saved /tmp/processedValidation/Dodge Challenger SRT8 2011/07983.jpg
# Processing image 7984 of 8144
# Saved /tmp/processedValidation/Spyker C8 Convertible 2009/07984.jpg
# Processing image 7985 of 8144
# Saved /tmp/processedValidation/GMC Savana Van 2012/07985.jpg
# Processing image 7986 of 8144
# Saved /tmp/processedValidation/Jeep Patriot SUV 2012/07986.jpg
# Processing image 7987 of 8144
# Saved /tmp/processedValidation/Toyota Camry Sedan 2012/07987.jpg
# Processing image 7988 of 8144
# Saved /tmp/processedValidation/Hyundai Sonata Hybrid Sedan 2012/07988.jpg
# Processing image 7989 of 8144
# Saved /tmp/processedValidation/Volkswagen Golf Hatchback 2012/07989.jpg
# Processing image 7990 of 8144
# Saved /tmp/processedValidation/Bentley Continental GT Coupe 2007/07990.jpg
# Processing image 7991 of 8144
# Saved /tmp/processedValidation/Land Rover Range Rover SUV 2012/07991.jpg
# Processing image 7992 of 8144
# Saved /tmp/processedValidation/Hyundai Genesis Sedan 2012/07992.jpg
# Processing image 7993 of 8144
# Saved /tmp/processedValidation/Ferrari 458 Italia Convertible 2012/07993.jpg
# Processing image 7994 of 8144
# Saved /tmp/processedValidation/BMW 6 Series Convertible 2007/07994.jpg
# Processing image 7995 of 8144
# Saved /tmp/processedValidation/Ford Freestar Minivan 2007/07995.jpg
# Processing image 7996 of 8144
# Saved /tmp/processedValidation/Nissan 240SX Coupe 1998/07996.jpg
# Processing image 7997 of 8144
# Saved /tmp/processedValidation/Infiniti QX56 SUV 2011/07997.jpg
# Processing image 7998 of 8144
# Saved /tmp/processedValidation/Chrysler Aspen SUV 2009/07998.jpg
# Processing image 7999 of 8144
# Saved /tmp/processedValidation/Chevrolet Silverado 1500 Classic Extended Cab 2007/07999.jpg
# Processing image 8000 of 8144
# Saved /tmp/processedValidation/Mercedes-Benz C-Class Sedan 2012/08000.jpg
# Processing image 8001 of 8144
# Saved /tmp/processedValidation/Jeep Compass SUV 2012/08001.jpg
# Processing image 8002 of 8144
# Saved /tmp/processedValidation/Mercedes-Benz 300-Class Convertible 1993/08002.jpg
# Processing image 8003 of 8144
# Saved /tmp/processedValidation/Hyundai Santa Fe SUV 2012/08003.jpg
# Processing image 8004 of 8144
# Saved /tmp/processedValidation/BMW 3 Series Wagon 2012/08004.jpg
# Processing image 8005 of 8144
# Saved /tmp/processedValidation/Acura TL Sedan 2012/08005.jpg
# Processing image 8006 of 8144
# Saved /tmp/processedValidation/Hyundai Azera Sedan 2012/08006.jpg
# Processing image 8007 of 8144
# Saved /tmp/processedValidation/BMW M6 Convertible 2010/08007.jpg
# Processing image 8008 of 8144
# Saved /tmp/processedValidation/Chevrolet Cobalt SS 2010/08008.jpg
# Processing image 8009 of 8144
# Saved /tmp/processedValidation/Mercedes-Benz C-Class Sedan 2012/08009.jpg
# Processing image 8010 of 8144
# Saved /tmp/processedValidation/Audi 100 Sedan 1994/08010.jpg
# Processing image 8011 of 8144
# Saved /tmp/processedValidation/AM General Hummer SUV 2000/08011.jpg
# Processing image 8012 of 8144
# Saved /tmp/processedValidation/Lamborghini Reventon Coupe 2008/08012.jpg
# Processing image 8013 of 8144
# Saved /tmp/processedValidation/GMC Savana Van 2012/08013.jpg
# Processing image 8014 of 8144
# Saved /tmp/processedValidation/Audi RS 4 Convertible 2008/08014.jpg
# Processing image 8015 of 8144
# Saved /tmp/processedValidation/Bentley Arnage Sedan 2009/08015.jpg
# Processing image 8016 of 8144
# Saved /tmp/processedValidation/Acura TSX Sedan 2012/08016.jpg
# Processing image 8017 of 8144
# Saved /tmp/processedValidation/Chevrolet Avalanche Crew Cab 2012/08017.jpg
# Processing image 8018 of 8144
# Saved /tmp/processedValidation/Acura Integra Type R 2001/08018.jpg
# Processing image 8019 of 8144
# Saved /tmp/processedValidation/Hyundai Sonata Sedan 2012/08019.jpg
# Processing image 8020 of 8144
# Saved /tmp/processedValidation/Dodge Ram Pickup 3500 Quad Cab 2009/08020.jpg
# Processing image 8021 of 8144
# Saved /tmp/processedValidation/BMW 1 Series Coupe 2012/08021.jpg
# Processing image 8022 of 8144
# Saved /tmp/processedValidation/Lamborghini Gallardo LP 570-4 Superleggera 2012/08022.jpg
# Processing image 8023 of 8144
# Saved /tmp/processedValidation/Infiniti G Coupe IPL 2012/08023.jpg
# Processing image 8024 of 8144
# Saved /tmp/processedValidation/Mazda Tribute SUV 2011/08024.jpg
# Processing image 8025 of 8144
# Saved /tmp/processedValidation/GMC Savana Van 2012/08025.jpg
# Processing image 8026 of 8144
# Saved /tmp/processedValidation/Audi S4 Sedan 2007/08026.jpg
# Processing image 8027 of 8144
# Saved /tmp/processedValidation/Audi A5 Coupe 2012/08027.jpg
# Processing image 8028 of 8144
# Saved /tmp/processedValidation/Audi A5 Coupe 2012/08028.jpg
# Processing image 8029 of 8144
# Saved /tmp/processedValidation/Ford F-450 Super Duty Crew Cab 2012/08029.jpg
# Processing image 8030 of 8144
# Saved /tmp/processedValidation/FIAT 500 Abarth 2012/08030.jpg
# Processing image 8031 of 8144
# Saved /tmp/processedValidation/AM General Hummer SUV 2000/08031.jpg
# Processing image 8032 of 8144
# Saved /tmp/processedValidation/BMW M3 Coupe 2012/08032.jpg
# Processing image 8033 of 8144
# Saved /tmp/processedValidation/BMW M6 Convertible 2010/08033.jpg
# Processing image 8034 of 8144
# Saved /tmp/processedValidation/Hyundai Sonata Sedan 2012/08034.jpg
# Processing image 8035 of 8144
# Saved /tmp/processedValidation/Chevrolet Malibu Sedan 2007/08035.jpg
# Processing image 8036 of 8144
# Saved /tmp/processedValidation/Toyota Camry Sedan 2012/08036.jpg
# Processing image 8037 of 8144
# Saved /tmp/processedValidation/Chevrolet Express Van 2007/08037.jpg
# Processing image 8038 of 8144
# Saved /tmp/processedValidation/Chrysler Crossfire Convertible 2008/08038.jpg
# Processing image 8039 of 8144
# Saved /tmp/processedValidation/Jeep Liberty SUV 2012/08039.jpg
# Processing image 8040 of 8144
# Saved /tmp/processedValidation/Chevrolet Corvette Ron Fellows Edition Z06 2007/08040.jpg
# Processing image 8041 of 8144
# Saved /tmp/processedValidation/Mercedes-Benz S-Class Sedan 2012/08041.jpg
# Processing image 8042 of 8144
# Saved /tmp/processedValidation/Buick Enclave SUV 2012/08042.jpg
# Processing image 8043 of 8144
# Saved /tmp/processedValidation/Audi 100 Sedan 1994/08043.jpg
# Processing image 8044 of 8144
# Saved /tmp/processedValidation/Aston Martin Virage Convertible 2012/08044.jpg
# Processing image 8045 of 8144
# Saved /tmp/processedValidation/Hyundai Elantra Touring Hatchback 2012/08045.jpg
# Processing image 8046 of 8144
# Saved /tmp/processedValidation/Toyota Corolla Sedan 2012/08046.jpg
# Processing image 8047 of 8144
# Saved /tmp/processedValidation/Chrysler 300 SRT-8 2010/08047.jpg
# Processing image 8048 of 8144
# Saved /tmp/processedValidation/BMW M6 Convertible 2010/08048.jpg
# Processing image 8049 of 8144
# Saved /tmp/processedValidation/Chevrolet Express Cargo Van 2007/08049.jpg
# Processing image 8050 of 8144
# Saved /tmp/processedValidation/Dodge Durango SUV 2012/08050.jpg
# Processing image 8051 of 8144
# Saved /tmp/processedValidation/Aston Martin Virage Coupe 2012/08051.jpg
# Processing image 8052 of 8144
# Saved /tmp/processedValidation/Land Rover Range Rover SUV 2012/08052.jpg
# Processing image 8053 of 8144
# Saved /tmp/processedValidation/Audi S4 Sedan 2007/08053.jpg
# Processing image 8054 of 8144
# Saved /tmp/processedValidation/Ford Fiesta Sedan 2012/08054.jpg
# Processing image 8055 of 8144
# Saved /tmp/processedValidation/Audi S5 Coupe 2012/08055.jpg
# Processing image 8056 of 8144
# Saved /tmp/processedValidation/GMC Savana Van 2012/08056.jpg
# Processing image 8057 of 8144
# Saved /tmp/processedValidation/Isuzu Ascender SUV 2008/08057.jpg
# Processing image 8058 of 8144
# Saved /tmp/processedValidation/BMW X5 SUV 2007/08058.jpg
# Processing image 8059 of 8144
# Saved /tmp/processedValidation/GMC Acadia SUV 2012/08059.jpg
# Processing image 8060 of 8144
# Saved /tmp/processedValidation/Jeep Patriot SUV 2012/08060.jpg
# Processing image 8061 of 8144
# Saved /tmp/processedValidation/Mercedes-Benz Sprinter Van 2012/08061.jpg
# Processing image 8062 of 8144
# Saved /tmp/processedValidation/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/08062.jpg
# Processing image 8063 of 8144
# Saved /tmp/processedValidation/GMC Acadia SUV 2012/08063.jpg
# Processing image 8064 of 8144
# Saved /tmp/processedValidation/Hyundai Tucson SUV 2012/08064.jpg
# Processing image 8065 of 8144
# Saved /tmp/processedValidation/Jeep Grand Cherokee SUV 2012/08065.jpg
# Processing image 8066 of 8144
# Saved /tmp/processedValidation/Ford Focus Sedan 2007/08066.jpg
# Processing image 8067 of 8144
# Saved /tmp/processedValidation/Lamborghini Reventon Coupe 2008/08067.jpg
# Processing image 8068 of 8144
# Saved /tmp/processedValidation/BMW X3 SUV 2012/08068.jpg
# Processing image 8069 of 8144
# Saved /tmp/processedValidation/Land Rover LR2 SUV 2012/08069.jpg
# Processing image 8070 of 8144
# Saved /tmp/processedValidation/Chevrolet Tahoe Hybrid SUV 2012/08070.jpg
# Processing image 8071 of 8144
# Saved /tmp/processedValidation/Volvo C30 Hatchback 2012/08071.jpg
# Processing image 8072 of 8144
# Saved /tmp/processedValidation/Honda Odyssey Minivan 2012/08072.jpg
# Processing image 8073 of 8144
# Saved /tmp/processedValidation/Bentley Continental GT Coupe 2012/08073.jpg
# Processing image 8074 of 8144
# Saved /tmp/processedValidation/Chevrolet Sonic Sedan 2012/08074.jpg
# Processing image 8075 of 8144
# Saved /tmp/processedValidation/Chevrolet Sonic Sedan 2012/08075.jpg
# Processing image 8076 of 8144
# Saved /tmp/processedValidation/Fisker Karma Sedan 2012/08076.jpg
# Processing image 8077 of 8144
# Saved /tmp/processedValidation/Chevrolet Cobalt SS 2010/08077.jpg
# Processing image 8078 of 8144
# Saved /tmp/processedValidation/Suzuki Kizashi Sedan 2012/08078.jpg
# Processing image 8079 of 8144
# Saved /tmp/processedValidation/Ford F-150 Regular Cab 2007/08079.jpg
# Processing image 8080 of 8144
# Saved /tmp/processedValidation/Chevrolet Silverado 1500 Regular Cab 2012/08080.jpg
# Processing image 8081 of 8144
# Saved /tmp/processedValidation/Audi S4 Sedan 2012/08081.jpg
# Processing image 8082 of 8144
# Saved /tmp/processedValidation/BMW X3 SUV 2012/08082.jpg
# Processing image 8083 of 8144
# Saved /tmp/processedValidation/Mercedes-Benz E-Class Sedan 2012/08083.jpg
# Processing image 8084 of 8144
# Saved /tmp/processedValidation/Hyundai Veloster Hatchback 2012/08084.jpg
# Processing image 8085 of 8144
# Saved /tmp/processedValidation/Aston Martin Virage Convertible 2012/08085.jpg
# Processing image 8086 of 8144
# Saved /tmp/processedValidation/Audi RS 4 Convertible 2008/08086.jpg
# Processing image 8087 of 8144
# Saved /tmp/processedValidation/Geo Metro Convertible 1993/08087.jpg
# Processing image 8088 of 8144
# Saved /tmp/processedValidation/Volkswagen Golf Hatchback 2012/08088.jpg
# Processing image 8089 of 8144
# Saved /tmp/processedValidation/Honda Accord Sedan 2012/08089.jpg
# Processing image 8090 of 8144
# Saved /tmp/processedValidation/Dodge Dakota Crew Cab 2010/08090.jpg
# Processing image 8091 of 8144
# Saved /tmp/processedValidation/Dodge Durango SUV 2007/08091.jpg
# Processing image 8092 of 8144
# Saved /tmp/processedValidation/Dodge Ram Pickup 3500 Quad Cab 2009/08092.jpg
# Processing image 8093 of 8144
# Saved /tmp/processedValidation/Ferrari California Convertible 2012/08093.jpg
# Processing image 8094 of 8144
# Saved /tmp/processedValidation/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/08094.jpg
# Processing image 8095 of 8144
# Saved /tmp/processedValidation/Bugatti Veyron 16.4 Convertible 2009/08095.jpg
# Processing image 8096 of 8144
# Saved /tmp/processedValidation/Aston Martin V8 Vantage Convertible 2012/08096.jpg
# Processing image 8097 of 8144
# Saved /tmp/processedValidation/Chevrolet Corvette Convertible 2012/08097.jpg
# Processing image 8098 of 8144
# Saved /tmp/processedValidation/Suzuki Aerio Sedan 2007/08098.jpg
# Processing image 8099 of 8144
# Saved /tmp/processedValidation/Ford E-Series Wagon Van 2012/08099.jpg
# Processing image 8100 of 8144
# Saved /tmp/processedValidation/Chrysler PT Cruiser Convertible 2008/08100.jpg
# Processing image 8101 of 8144
# Saved /tmp/processedValidation/Nissan Leaf Hatchback 2012/08101.jpg
# Processing image 8102 of 8144
# Saved /tmp/processedValidation/Mercedes-Benz E-Class Sedan 2012/08102.jpg
# Processing image 8103 of 8144
# Saved /tmp/processedValidation/Toyota 4Runner SUV 2012/08103.jpg
# Processing image 8104 of 8144
# Saved /tmp/processedValidation/Toyota Camry Sedan 2012/08104.jpg
# Processing image 8105 of 8144
# Saved /tmp/processedValidation/Dodge Caravan Minivan 1997/08105.jpg
# Processing image 8106 of 8144
# Saved /tmp/processedValidation/Lamborghini Aventador Coupe 2012/08106.jpg
# Processing image 8107 of 8144
# Saved /tmp/processedValidation/Chrysler 300 SRT-8 2010/08107.jpg
# Processing image 8108 of 8144
# Saved /tmp/processedValidation/Chevrolet HHR SS 2010/08108.jpg
# Processing image 8109 of 8144
# Saved /tmp/processedValidation/Land Rover LR2 SUV 2012/08109.jpg
# Processing image 8110 of 8144
# Saved /tmp/processedValidation/Toyota Sequoia SUV 2012/08110.jpg
# Processing image 8111 of 8144
# Saved /tmp/processedValidation/Nissan Juke Hatchback 2012/08111.jpg
# Processing image 8112 of 8144
# Saved /tmp/processedValidation/Dodge Charger SRT-8 2009/08112.jpg
# Processing image 8113 of 8144
# Saved /tmp/processedValidation/Ford Fiesta Sedan 2012/08113.jpg
# Processing image 8114 of 8144
# Saved /tmp/processedValidation/Mercedes-Benz Sprinter Van 2012/08114.jpg
# Processing image 8115 of 8144
# Saved /tmp/processedValidation/McLaren MP4-12C Coupe 2012/08115.jpg
# Processing image 8116 of 8144
# Saved /tmp/processedValidation/Mercedes-Benz SL-Class Coupe 2009/08116.jpg
# Processing image 8117 of 8144
# Saved /tmp/processedValidation/Chevrolet Silverado 1500 Regular Cab 2012/08117.jpg
# Processing image 8118 of 8144
# Saved /tmp/processedValidation/BMW X5 SUV 2007/08118.jpg
# Processing image 8119 of 8144
# Saved /tmp/processedValidation/Chevrolet Malibu Hybrid Sedan 2010/08119.jpg
# Processing image 8120 of 8144
# Saved /tmp/processedValidation/Honda Accord Coupe 2012/08120.jpg
# Processing image 8121 of 8144
# Saved /tmp/processedValidation/Lamborghini Diablo Coupe 2001/08121.jpg
# Processing image 8122 of 8144
# Saved /tmp/processedValidation/Cadillac SRX SUV 2012/08122.jpg
# Processing image 8123 of 8144
# Saved /tmp/processedValidation/Scion xD Hatchback 2012/08123.jpg
# Processing image 8124 of 8144
# Saved /tmp/processedValidation/Bentley Arnage Sedan 2009/08124.jpg
# Processing image 8125 of 8144
# Saved /tmp/processedValidation/Chevrolet Corvette Convertible 2012/08125.jpg
# Processing image 8126 of 8144
# Saved /tmp/processedValidation/Ford Fiesta Sedan 2012/08126.jpg
# Processing image 8127 of 8144
# Saved /tmp/processedValidation/Acura TSX Sedan 2012/08127.jpg
# Processing image 8128 of 8144
# Saved /tmp/processedValidation/Ford GT Coupe 2006/08128.jpg
# Processing image 8129 of 8144
# Saved /tmp/processedValidation/Bugatti Veyron 16.4 Coupe 2009/08129.jpg
# Processing image 8130 of 8144
# Saved /tmp/processedValidation/Bugatti Veyron 16.4 Coupe 2009/08130.jpg
# Processing image 8131 of 8144
# Saved /tmp/processedValidation/GMC Savana Van 2012/08131.jpg
# Processing image 8132 of 8144
# Saved /tmp/processedValidation/Lamborghini Diablo Coupe 2001/08132.jpg
# Processing image 8133 of 8144
# Saved /tmp/processedValidation/Acura TL Sedan 2012/08133.jpg
# Processing image 8134 of 8144
# Saved /tmp/processedValidation/HUMMER H3T Crew Cab 2010/08134.jpg
# Processing image 8135 of 8144
# Saved /tmp/processedValidation/Dodge Caravan Minivan 1997/08135.jpg
# Processing image 8136 of 8144
# Saved /tmp/processedValidation/Toyota Camry Sedan 2012/08136.jpg
# Processing image 8137 of 8144
# Saved /tmp/processedValidation/Audi 100 Sedan 1994/08137.jpg
# Processing image 8138 of 8144
# Saved /tmp/processedValidation/Suzuki Aerio Sedan 2007/08138.jpg
# Processing image 8139 of 8144
# Saved /tmp/processedValidation/Toyota Corolla Sedan 2012/08139.jpg
# Processing image 8140 of 8144
# Saved /tmp/processedValidation/Chrysler Town and Country Minivan 2012/08140.jpg
# Processing image 8141 of 8144
# Saved /tmp/processedValidation/smart fortwo Convertible 2012/08141.jpg
# Processing image 8142 of 8144
# Saved /tmp/processedValidation/Mercedes-Benz SL-Class Coupe 2009/08142.jpg
# Processing image 8143 of 8144
# Saved /tmp/processedValidation/Ford GT Coupe 2006/08143.jpg
# Processing image 8144 of 8144
# Saved /tmp/processedValidation/Audi 100 Sedan 1994/08144.jpg
# ------------------------
# Training images preprocessing complete.

# %%
"""
Preprocess Testing Images
Gets all training images and crops by bounding box, saves to a new directory
"""
print(len(testLabels), "images to process.")
Path("/tmp/processedTest").mkdir(parents=True, exist_ok=True)
Path("/tmp/boundedTest").mkdir(parents=True, exist_ok=True)
count = 1
for l in testLabels:
    print('Processing image', count, 'of', len(testLabels))
    x1 = l[0]
    y1 = l[1]
    x2 = l[2]
    y2 = l[3]
    filename = l[4]
    c_num = testDict.get(filename)
    classAppend = classDict.get(int(c_num)) + '/'
    address = "/tmp/test/cars_test/" + filename
    saveDir = "/tmp/processedTest/" + classAppend
    im = PIL.Image.open(address)
    region = im.crop((x1, y1, x2, y2))
    Path(saveDir).mkdir(parents=True, exist_ok=True)
    saveAddress = saveDir + filename
    saveAddress2 = "/tmp/boundedTest/" + filename
    region.save(saveAddress2)    
    print('Saved', saveAddress2)
    region.save(saveAddress)    
    print('Saved', saveAddress)
    count = count + 1
print("------------------------")
print("Testing images preprocessing complete.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Saved /tmp/boundedTest/06376.jpg
# Saved /tmp/processedTest/Rolls-Royce Phantom Sedan 2012/06376.jpg
# Processing image 6377 of 8041
# Saved /tmp/boundedTest/06377.jpg
# Saved /tmp/processedTest/Dodge Charger SRT-8 2009/06377.jpg
# Processing image 6378 of 8041
# Saved /tmp/boundedTest/06378.jpg
# Saved /tmp/processedTest/Dodge Caravan Minivan 1997/06378.jpg
# Processing image 6379 of 8041
# Saved /tmp/boundedTest/06379.jpg
# Saved /tmp/processedTest/Audi TT RS Coupe 2012/06379.jpg
# Processing image 6380 of 8041
# Saved /tmp/boundedTest/06380.jpg
# Saved /tmp/processedTest/Nissan 240SX Coupe 1998/06380.jpg
# Processing image 6381 of 8041
# Saved /tmp/boundedTest/06381.jpg
# Saved /tmp/processedTest/Hyundai Sonata Sedan 2012/06381.jpg
# Processing image 6382 of 8041
# Saved /tmp/boundedTest/06382.jpg
# Saved /tmp/processedTest/Bentley Arnage Sedan 2009/06382.jpg
# Processing image 6383 of 8041
# Saved /tmp/boundedTest/06383.jpg
# Saved /tmp/processedTest/Bentley Continental Flying Spur Sedan 2007/06383.jpg
# Processing image 6384 of 8041
# Saved /tmp/boundedTest/06384.jpg
# Saved /tmp/processedTest/Ford Freestar Minivan 2007/06384.jpg
# Processing image 6385 of 8041
# Saved /tmp/boundedTest/06385.jpg
# Saved /tmp/processedTest/GMC Savana Van 2012/06385.jpg
# Processing image 6386 of 8041
# Saved /tmp/boundedTest/06386.jpg
# Saved /tmp/processedTest/Nissan Leaf Hatchback 2012/06386.jpg
# Processing image 6387 of 8041
# Saved /tmp/boundedTest/06387.jpg
# Saved /tmp/processedTest/Aston Martin Virage Coupe 2012/06387.jpg
# Processing image 6388 of 8041
# Saved /tmp/boundedTest/06388.jpg
# Saved /tmp/processedTest/BMW 1 Series Coupe 2012/06388.jpg
# Processing image 6389 of 8041
# Saved /tmp/boundedTest/06389.jpg
# Saved /tmp/processedTest/Cadillac Escalade EXT Crew Cab 2007/06389.jpg
# Processing image 6390 of 8041
# Saved /tmp/boundedTest/06390.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Classic Extended Cab 2007/06390.jpg
# Processing image 6391 of 8041
# Saved /tmp/boundedTest/06391.jpg
# Saved /tmp/processedTest/Nissan NV Passenger Van 2012/06391.jpg
# Processing image 6392 of 8041
# Saved /tmp/boundedTest/06392.jpg
# Saved /tmp/processedTest/HUMMER H3T Crew Cab 2010/06392.jpg
# Processing image 6393 of 8041
# Saved /tmp/boundedTest/06393.jpg
# Saved /tmp/processedTest/Dodge Journey SUV 2012/06393.jpg
# Processing image 6394 of 8041
# Saved /tmp/boundedTest/06394.jpg
# Saved /tmp/processedTest/Ram C/V Cargo Van Minivan 2012/06394.jpg
# Processing image 6395 of 8041
# Saved /tmp/boundedTest/06395.jpg
# Saved /tmp/processedTest/BMW X3 SUV 2012/06395.jpg
# Processing image 6396 of 8041
# Saved /tmp/boundedTest/06396.jpg
# Saved /tmp/processedTest/Spyker C8 Convertible 2009/06396.jpg
# Processing image 6397 of 8041
# Saved /tmp/boundedTest/06397.jpg
# Saved /tmp/processedTest/Chevrolet Corvette Convertible 2012/06397.jpg
# Processing image 6398 of 8041
# Saved /tmp/boundedTest/06398.jpg
# Saved /tmp/processedTest/Chevrolet Malibu Hybrid Sedan 2010/06398.jpg
# Processing image 6399 of 8041
# Saved /tmp/boundedTest/06399.jpg
# Saved /tmp/processedTest/Chevrolet TrailBlazer SS 2009/06399.jpg
# Processing image 6400 of 8041
# Saved /tmp/boundedTest/06400.jpg
# Saved /tmp/processedTest/Chevrolet Avalanche Crew Cab 2012/06400.jpg
# Processing image 6401 of 8041
# Saved /tmp/boundedTest/06401.jpg
# Saved /tmp/processedTest/Infiniti G Coupe IPL 2012/06401.jpg
# Processing image 6402 of 8041
# Saved /tmp/boundedTest/06402.jpg
# Saved /tmp/processedTest/Bugatti Veyron 16.4 Coupe 2009/06402.jpg
# Processing image 6403 of 8041
# Saved /tmp/boundedTest/06403.jpg
# Saved /tmp/processedTest/Geo Metro Convertible 1993/06403.jpg
# Processing image 6404 of 8041
# Saved /tmp/boundedTest/06404.jpg
# Saved /tmp/processedTest/Audi TTS Coupe 2012/06404.jpg
# Processing image 6405 of 8041
# Saved /tmp/boundedTest/06405.jpg
# Saved /tmp/processedTest/Cadillac Escalade EXT Crew Cab 2007/06405.jpg
# Processing image 6406 of 8041
# Saved /tmp/boundedTest/06406.jpg
# Saved /tmp/processedTest/Volkswagen Golf Hatchback 1991/06406.jpg
# Processing image 6407 of 8041
# Saved /tmp/boundedTest/06407.jpg
# Saved /tmp/processedTest/Dodge Charger Sedan 2012/06407.jpg
# Processing image 6408 of 8041
# Saved /tmp/boundedTest/06408.jpg
# Saved /tmp/processedTest/Rolls-Royce Ghost Sedan 2012/06408.jpg
# Processing image 6409 of 8041
# Saved /tmp/boundedTest/06409.jpg
# Saved /tmp/processedTest/Chevrolet Malibu Sedan 2007/06409.jpg
# Processing image 6410 of 8041
# Saved /tmp/boundedTest/06410.jpg
# Saved /tmp/processedTest/Buick Verano Sedan 2012/06410.jpg
# Processing image 6411 of 8041
# Saved /tmp/boundedTest/06411.jpg
# Saved /tmp/processedTest/Ford Ranger SuperCab 2011/06411.jpg
# Processing image 6412 of 8041
# Saved /tmp/boundedTest/06412.jpg
# Saved /tmp/processedTest/Cadillac CTS-V Sedan 2012/06412.jpg
# Processing image 6413 of 8041
# Saved /tmp/boundedTest/06413.jpg
# Saved /tmp/processedTest/Chrysler Aspen SUV 2009/06413.jpg
# Processing image 6414 of 8041
# Saved /tmp/boundedTest/06414.jpg
# Saved /tmp/processedTest/Dodge Sprinter Cargo Van 2009/06414.jpg
# Processing image 6415 of 8041
# Saved /tmp/boundedTest/06415.jpg
# Saved /tmp/processedTest/Audi TT Hatchback 2011/06415.jpg
# Processing image 6416 of 8041
# Saved /tmp/boundedTest/06416.jpg
# Saved /tmp/processedTest/Toyota Corolla Sedan 2012/06416.jpg
# Processing image 6417 of 8041
# Saved /tmp/boundedTest/06417.jpg
# Saved /tmp/processedTest/BMW 3 Series Wagon 2012/06417.jpg
# Processing image 6418 of 8041
# Saved /tmp/boundedTest/06418.jpg
# Saved /tmp/processedTest/Jeep Patriot SUV 2012/06418.jpg
# Processing image 6419 of 8041
# Saved /tmp/boundedTest/06419.jpg
# Saved /tmp/processedTest/Ford F-150 Regular Cab 2007/06419.jpg
# Processing image 6420 of 8041
# Saved /tmp/boundedTest/06420.jpg
# Saved /tmp/processedTest/Ford GT Coupe 2006/06420.jpg
# Processing image 6421 of 8041
# Saved /tmp/boundedTest/06421.jpg
# Saved /tmp/processedTest/Dodge Charger SRT-8 2009/06421.jpg
# Processing image 6422 of 8041
# Saved /tmp/boundedTest/06422.jpg
# Saved /tmp/processedTest/Ford Mustang Convertible 2007/06422.jpg
# Processing image 6423 of 8041
# Saved /tmp/boundedTest/06423.jpg
# Saved /tmp/processedTest/Chevrolet Sonic Sedan 2012/06423.jpg
# Processing image 6424 of 8041
# Saved /tmp/boundedTest/06424.jpg
# Saved /tmp/processedTest/Chevrolet HHR SS 2010/06424.jpg
# Processing image 6425 of 8041
# Saved /tmp/boundedTest/06425.jpg
# Saved /tmp/processedTest/Dodge Ram Pickup 3500 Quad Cab 2009/06425.jpg
# Processing image 6426 of 8041
# Saved /tmp/boundedTest/06426.jpg
# Saved /tmp/processedTest/Chevrolet TrailBlazer SS 2009/06426.jpg
# Processing image 6427 of 8041
# Saved /tmp/boundedTest/06427.jpg
# Saved /tmp/processedTest/Audi R8 Coupe 2012/06427.jpg
# Processing image 6428 of 8041
# Saved /tmp/boundedTest/06428.jpg
# Saved /tmp/processedTest/Dodge Dakota Club Cab 2007/06428.jpg
# Processing image 6429 of 8041
# Saved /tmp/boundedTest/06429.jpg
# Saved /tmp/processedTest/Jaguar XK XKR 2012/06429.jpg
# Processing image 6430 of 8041
# Saved /tmp/boundedTest/06430.jpg
# Saved /tmp/processedTest/Dodge Ram Pickup 3500 Quad Cab 2009/06430.jpg
# Processing image 6431 of 8041
# Saved /tmp/boundedTest/06431.jpg
# Saved /tmp/processedTest/Dodge Ram Pickup 3500 Quad Cab 2009/06431.jpg
# Processing image 6432 of 8041
# Saved /tmp/boundedTest/06432.jpg
# Saved /tmp/processedTest/Chevrolet Camaro Convertible 2012/06432.jpg
# Processing image 6433 of 8041
# Saved /tmp/boundedTest/06433.jpg
# Saved /tmp/processedTest/GMC Acadia SUV 2012/06433.jpg
# Processing image 6434 of 8041
# Saved /tmp/boundedTest/06434.jpg
# Saved /tmp/processedTest/Bentley Continental Supersports Conv. Convertible 2012/06434.jpg
# Processing image 6435 of 8041
# Saved /tmp/boundedTest/06435.jpg
# Saved /tmp/processedTest/Mitsubishi Lancer Sedan 2012/06435.jpg
# Processing image 6436 of 8041
# Saved /tmp/boundedTest/06436.jpg
# Saved /tmp/processedTest/Mitsubishi Lancer Sedan 2012/06436.jpg
# Processing image 6437 of 8041
# Saved /tmp/boundedTest/06437.jpg
# Saved /tmp/processedTest/Ford Fiesta Sedan 2012/06437.jpg
# Processing image 6438 of 8041
# Saved /tmp/boundedTest/06438.jpg
# Saved /tmp/processedTest/Nissan Juke Hatchback 2012/06438.jpg
# Processing image 6439 of 8041
# Saved /tmp/boundedTest/06439.jpg
# Saved /tmp/processedTest/Audi S5 Convertible 2012/06439.jpg
# Processing image 6440 of 8041
# Saved /tmp/boundedTest/06440.jpg
# Saved /tmp/processedTest/GMC Yukon Hybrid SUV 2012/06440.jpg
# Processing image 6441 of 8041
# Saved /tmp/boundedTest/06441.jpg
# Saved /tmp/processedTest/Fisker Karma Sedan 2012/06441.jpg
# Processing image 6442 of 8041
# Saved /tmp/boundedTest/06442.jpg
# Saved /tmp/processedTest/Geo Metro Convertible 1993/06442.jpg
# Processing image 6443 of 8041
# Saved /tmp/boundedTest/06443.jpg
# Saved /tmp/processedTest/Audi TT Hatchback 2011/06443.jpg
# Processing image 6444 of 8041
# Saved /tmp/boundedTest/06444.jpg
# Saved /tmp/processedTest/Chevrolet Express Cargo Van 2007/06444.jpg
# Processing image 6445 of 8041
# Saved /tmp/boundedTest/06445.jpg
# Saved /tmp/processedTest/Hyundai Elantra Touring Hatchback 2012/06445.jpg
# Processing image 6446 of 8041
# Saved /tmp/boundedTest/06446.jpg
# Saved /tmp/processedTest/GMC Acadia SUV 2012/06446.jpg
# Processing image 6447 of 8041
# Saved /tmp/boundedTest/06447.jpg
# Saved /tmp/processedTest/Dodge Durango SUV 2012/06447.jpg
# Processing image 6448 of 8041
# Saved /tmp/boundedTest/06448.jpg
# Saved /tmp/processedTest/GMC Savana Van 2012/06448.jpg
# Processing image 6449 of 8041
# Saved /tmp/boundedTest/06449.jpg
# Saved /tmp/processedTest/Bentley Continental Supersports Conv. Convertible 2012/06449.jpg
# Processing image 6450 of 8041
# Saved /tmp/boundedTest/06450.jpg
# Saved /tmp/processedTest/Chevrolet Malibu Hybrid Sedan 2010/06450.jpg
# Processing image 6451 of 8041
# Saved /tmp/boundedTest/06451.jpg
# Saved /tmp/processedTest/Bentley Continental GT Coupe 2012/06451.jpg
# Processing image 6452 of 8041
# Saved /tmp/boundedTest/06452.jpg
# Saved /tmp/processedTest/Chevrolet Malibu Sedan 2007/06452.jpg
# Processing image 6453 of 8041
# Saved /tmp/boundedTest/06453.jpg
# Saved /tmp/processedTest/FIAT 500 Convertible 2012/06453.jpg
# Processing image 6454 of 8041
# Saved /tmp/boundedTest/06454.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/06454.jpg
# Processing image 6455 of 8041
# Saved /tmp/boundedTest/06455.jpg
# Saved /tmp/processedTest/Cadillac CTS-V Sedan 2012/06455.jpg
# Processing image 6456 of 8041
# Saved /tmp/boundedTest/06456.jpg
# Saved /tmp/processedTest/GMC Canyon Extended Cab 2012/06456.jpg
# Processing image 6457 of 8041
# Saved /tmp/boundedTest/06457.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Classic Extended Cab 2007/06457.jpg
# Processing image 6458 of 8041
# Saved /tmp/boundedTest/06458.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Extended Cab 2012/06458.jpg
# Processing image 6459 of 8041
# Saved /tmp/boundedTest/06459.jpg
# Saved /tmp/processedTest/Acura TL Type-S 2008/06459.jpg
# Processing image 6460 of 8041
# Saved /tmp/boundedTest/06460.jpg
# Saved /tmp/processedTest/Dodge Durango SUV 2012/06460.jpg
# Processing image 6461 of 8041
# Saved /tmp/boundedTest/06461.jpg
# Saved /tmp/processedTest/Chevrolet HHR SS 2010/06461.jpg
# Processing image 6462 of 8041
# Saved /tmp/boundedTest/06462.jpg
# Saved /tmp/processedTest/Mercedes-Benz SL-Class Coupe 2009/06462.jpg
# Processing image 6463 of 8041
# Saved /tmp/boundedTest/06463.jpg
# Saved /tmp/processedTest/Aston Martin V8 Vantage Coupe 2012/06463.jpg
# Processing image 6464 of 8041
# Saved /tmp/boundedTest/06464.jpg
# Saved /tmp/processedTest/Chrysler Sebring Convertible 2010/06464.jpg
# Processing image 6465 of 8041
# Saved /tmp/boundedTest/06465.jpg
# Saved /tmp/processedTest/Cadillac SRX SUV 2012/06465.jpg
# Processing image 6466 of 8041
# Saved /tmp/boundedTest/06466.jpg
# Saved /tmp/processedTest/Bentley Continental GT Coupe 2012/06466.jpg
# Processing image 6467 of 8041
# Saved /tmp/boundedTest/06467.jpg
# Saved /tmp/processedTest/Fisker Karma Sedan 2012/06467.jpg
# Processing image 6468 of 8041
# Saved /tmp/boundedTest/06468.jpg
# Saved /tmp/processedTest/Acura TL Sedan 2012/06468.jpg
# Processing image 6469 of 8041
# Saved /tmp/boundedTest/06469.jpg
# Saved /tmp/processedTest/Acura RL Sedan 2012/06469.jpg
# Processing image 6470 of 8041
# Saved /tmp/boundedTest/06470.jpg
# Saved /tmp/processedTest/HUMMER H2 SUT Crew Cab 2009/06470.jpg
# Processing image 6471 of 8041
# Saved /tmp/boundedTest/06471.jpg
# Saved /tmp/processedTest/Chevrolet Malibu Hybrid Sedan 2010/06471.jpg
# Processing image 6472 of 8041
# Saved /tmp/boundedTest/06472.jpg
# Saved /tmp/processedTest/Bentley Continental Supersports Conv. Convertible 2012/06472.jpg
# Processing image 6473 of 8041
# Saved /tmp/boundedTest/06473.jpg
# Saved /tmp/processedTest/Hyundai Azera Sedan 2012/06473.jpg
# Processing image 6474 of 8041
# Saved /tmp/boundedTest/06474.jpg
# Saved /tmp/processedTest/Chevrolet Monte Carlo Coupe 2007/06474.jpg
# Processing image 6475 of 8041
# Saved /tmp/boundedTest/06475.jpg
# Saved /tmp/processedTest/Jeep Wrangler SUV 2012/06475.jpg
# Processing image 6476 of 8041
# Saved /tmp/boundedTest/06476.jpg
# Saved /tmp/processedTest/Honda Odyssey Minivan 2012/06476.jpg
# Processing image 6477 of 8041
# Saved /tmp/boundedTest/06477.jpg
# Saved /tmp/processedTest/Mercedes-Benz E-Class Sedan 2012/06477.jpg
# Processing image 6478 of 8041
# Saved /tmp/boundedTest/06478.jpg
# Saved /tmp/processedTest/Acura TL Sedan 2012/06478.jpg
# Processing image 6479 of 8041
# Saved /tmp/boundedTest/06479.jpg
# Saved /tmp/processedTest/smart fortwo Convertible 2012/06479.jpg
# Processing image 6480 of 8041
# Saved /tmp/boundedTest/06480.jpg
# Saved /tmp/processedTest/Acura TSX Sedan 2012/06480.jpg
# Processing image 6481 of 8041
# Saved /tmp/boundedTest/06481.jpg
# Saved /tmp/processedTest/Lamborghini Gallardo LP 570-4 Superleggera 2012/06481.jpg
# Processing image 6482 of 8041
# Saved /tmp/boundedTest/06482.jpg
# Saved /tmp/processedTest/Nissan Juke Hatchback 2012/06482.jpg
# Processing image 6483 of 8041
# Saved /tmp/boundedTest/06483.jpg
# Saved /tmp/processedTest/Dodge Challenger SRT8 2011/06483.jpg
# Processing image 6484 of 8041
# Saved /tmp/boundedTest/06484.jpg
# Saved /tmp/processedTest/Chrysler Sebring Convertible 2010/06484.jpg
# Processing image 6485 of 8041
# Saved /tmp/boundedTest/06485.jpg
# Saved /tmp/processedTest/Tesla Model S Sedan 2012/06485.jpg
# Processing image 6486 of 8041
# Saved /tmp/boundedTest/06486.jpg
# Saved /tmp/processedTest/Chevrolet Impala Sedan 2007/06486.jpg
# Processing image 6487 of 8041
# Saved /tmp/boundedTest/06487.jpg
# Saved /tmp/processedTest/Hyundai Santa Fe SUV 2012/06487.jpg
# Processing image 6488 of 8041
# Saved /tmp/boundedTest/06488.jpg
# Saved /tmp/processedTest/BMW Z4 Convertible 2012/06488.jpg
# Processing image 6489 of 8041
# Saved /tmp/boundedTest/06489.jpg
# Saved /tmp/processedTest/Mercedes-Benz E-Class Sedan 2012/06489.jpg
# Processing image 6490 of 8041
# Saved /tmp/boundedTest/06490.jpg
# Saved /tmp/processedTest/Audi TT RS Coupe 2012/06490.jpg
# Processing image 6491 of 8041
# Saved /tmp/boundedTest/06491.jpg
# Saved /tmp/processedTest/Ford Focus Sedan 2007/06491.jpg
# Processing image 6492 of 8041
# Saved /tmp/boundedTest/06492.jpg
# Saved /tmp/processedTest/Ferrari 458 Italia Coupe 2012/06492.jpg
# Processing image 6493 of 8041
# Saved /tmp/boundedTest/06493.jpg
# Saved /tmp/processedTest/Dodge Caravan Minivan 1997/06493.jpg
# Processing image 6494 of 8041
# Saved /tmp/boundedTest/06494.jpg
# Saved /tmp/processedTest/HUMMER H2 SUT Crew Cab 2009/06494.jpg
# Processing image 6495 of 8041
# Saved /tmp/boundedTest/06495.jpg
# Saved /tmp/processedTest/Dodge Durango SUV 2012/06495.jpg
# Processing image 6496 of 8041
# Saved /tmp/boundedTest/06496.jpg
# Saved /tmp/processedTest/Bentley Continental Flying Spur Sedan 2007/06496.jpg
# Processing image 6497 of 8041
# Saved /tmp/boundedTest/06497.jpg
# Saved /tmp/processedTest/Chrysler Aspen SUV 2009/06497.jpg
# Processing image 6498 of 8041
# Saved /tmp/boundedTest/06498.jpg
# Saved /tmp/processedTest/Hyundai Tucson SUV 2012/06498.jpg
# Processing image 6499 of 8041
# Saved /tmp/boundedTest/06499.jpg
# Saved /tmp/processedTest/Mercedes-Benz E-Class Sedan 2012/06499.jpg
# Processing image 6500 of 8041
# Saved /tmp/boundedTest/06500.jpg
# Saved /tmp/processedTest/Chevrolet HHR SS 2010/06500.jpg
# Processing image 6501 of 8041
# Saved /tmp/boundedTest/06501.jpg
# Saved /tmp/processedTest/Bugatti Veyron 16.4 Coupe 2009/06501.jpg
# Processing image 6502 of 8041
# Saved /tmp/boundedTest/06502.jpg
# Saved /tmp/processedTest/Ford Edge SUV 2012/06502.jpg
# Processing image 6503 of 8041
# Saved /tmp/boundedTest/06503.jpg
# Saved /tmp/processedTest/Honda Accord Coupe 2012/06503.jpg
# Processing image 6504 of 8041
# Saved /tmp/boundedTest/06504.jpg
# Saved /tmp/processedTest/Jeep Compass SUV 2012/06504.jpg
# Processing image 6505 of 8041
# Saved /tmp/boundedTest/06505.jpg
# Saved /tmp/processedTest/GMC Savana Van 2012/06505.jpg
# Processing image 6506 of 8041
# Saved /tmp/boundedTest/06506.jpg
# Saved /tmp/processedTest/BMW X6 SUV 2012/06506.jpg
# Processing image 6507 of 8041
# Saved /tmp/boundedTest/06507.jpg
# Saved /tmp/processedTest/Jeep Wrangler SUV 2012/06507.jpg
# Processing image 6508 of 8041
# Saved /tmp/boundedTest/06508.jpg
# Saved /tmp/processedTest/Isuzu Ascender SUV 2008/06508.jpg
# Processing image 6509 of 8041
# Saved /tmp/boundedTest/06509.jpg
# Saved /tmp/processedTest/Land Rover Range Rover SUV 2012/06509.jpg
# Processing image 6510 of 8041
# Saved /tmp/boundedTest/06510.jpg
# Saved /tmp/processedTest/Chevrolet TrailBlazer SS 2009/06510.jpg
# Processing image 6511 of 8041
# Saved /tmp/boundedTest/06511.jpg
# Saved /tmp/processedTest/Ford Focus Sedan 2007/06511.jpg
# Processing image 6512 of 8041
# Saved /tmp/boundedTest/06512.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/06512.jpg
# Processing image 6513 of 8041
# Saved /tmp/boundedTest/06513.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/06513.jpg
# Processing image 6514 of 8041
# Saved /tmp/boundedTest/06514.jpg
# Saved /tmp/processedTest/Audi S5 Coupe 2012/06514.jpg
# Processing image 6515 of 8041
# Saved /tmp/boundedTest/06515.jpg
# Saved /tmp/processedTest/Rolls-Royce Phantom Sedan 2012/06515.jpg
# Processing image 6516 of 8041
# Saved /tmp/boundedTest/06516.jpg
# Saved /tmp/processedTest/Dodge Challenger SRT8 2011/06516.jpg
# Processing image 6517 of 8041
# Saved /tmp/boundedTest/06517.jpg
# Saved /tmp/processedTest/BMW X3 SUV 2012/06517.jpg
# Processing image 6518 of 8041
# Saved /tmp/boundedTest/06518.jpg
# Saved /tmp/processedTest/Ferrari FF Coupe 2012/06518.jpg
# Processing image 6519 of 8041
# Saved /tmp/boundedTest/06519.jpg
# Saved /tmp/processedTest/Bentley Arnage Sedan 2009/06519.jpg
# Processing image 6520 of 8041
# Saved /tmp/boundedTest/06520.jpg
# Saved /tmp/processedTest/Dodge Challenger SRT8 2011/06520.jpg
# Processing image 6521 of 8041
# Saved /tmp/boundedTest/06521.jpg
# Saved /tmp/processedTest/Bentley Continental Flying Spur Sedan 2007/06521.jpg
# Processing image 6522 of 8041
# Saved /tmp/boundedTest/06522.jpg
# Saved /tmp/processedTest/Lincoln Town Car Sedan 2011/06522.jpg
# Processing image 6523 of 8041
# Saved /tmp/boundedTest/06523.jpg
# Saved /tmp/processedTest/Audi TT RS Coupe 2012/06523.jpg
# Processing image 6524 of 8041
# Saved /tmp/boundedTest/06524.jpg
# Saved /tmp/processedTest/Toyota 4Runner SUV 2012/06524.jpg
# Processing image 6525 of 8041
# Saved /tmp/boundedTest/06525.jpg
# Saved /tmp/processedTest/Chevrolet Express Van 2007/06525.jpg
# Processing image 6526 of 8041
# Saved /tmp/boundedTest/06526.jpg
# Saved /tmp/processedTest/Bentley Mulsanne Sedan 2011/06526.jpg
# Processing image 6527 of 8041
# Saved /tmp/boundedTest/06527.jpg
# Saved /tmp/processedTest/Honda Odyssey Minivan 2012/06527.jpg
# Processing image 6528 of 8041
# Saved /tmp/boundedTest/06528.jpg
# Saved /tmp/processedTest/Chevrolet Corvette Ron Fellows Edition Z06 2007/06528.jpg
# Processing image 6529 of 8041
# Saved /tmp/boundedTest/06529.jpg
# Saved /tmp/processedTest/GMC Acadia SUV 2012/06529.jpg
# Processing image 6530 of 8041
# Saved /tmp/boundedTest/06530.jpg
# Saved /tmp/processedTest/BMW M6 Convertible 2010/06530.jpg
# Processing image 6531 of 8041
# Saved /tmp/boundedTest/06531.jpg
# Saved /tmp/processedTest/Volvo XC90 SUV 2007/06531.jpg
# Processing image 6532 of 8041
# Saved /tmp/boundedTest/06532.jpg
# Saved /tmp/processedTest/BMW M5 Sedan 2010/06532.jpg
# Processing image 6533 of 8041
# Saved /tmp/boundedTest/06533.jpg
# Saved /tmp/processedTest/Dodge Ram Pickup 3500 Quad Cab 2009/06533.jpg
# Processing image 6534 of 8041
# Saved /tmp/boundedTest/06534.jpg
# Saved /tmp/processedTest/Audi TTS Coupe 2012/06534.jpg
# Processing image 6535 of 8041
# Saved /tmp/boundedTest/06535.jpg
# Saved /tmp/processedTest/Volkswagen Golf Hatchback 2012/06535.jpg
# Processing image 6536 of 8041
# Saved /tmp/boundedTest/06536.jpg
# Saved /tmp/processedTest/Mercedes-Benz C-Class Sedan 2012/06536.jpg
# Processing image 6537 of 8041
# Saved /tmp/boundedTest/06537.jpg
# Saved /tmp/processedTest/Volvo 240 Sedan 1993/06537.jpg
# Processing image 6538 of 8041
# Saved /tmp/boundedTest/06538.jpg
# Saved /tmp/processedTest/GMC Acadia SUV 2012/06538.jpg
# Processing image 6539 of 8041
# Saved /tmp/boundedTest/06539.jpg
# Saved /tmp/processedTest/Toyota Camry Sedan 2012/06539.jpg
# Processing image 6540 of 8041
# Saved /tmp/boundedTest/06540.jpg
# Saved /tmp/processedTest/Toyota Camry Sedan 2012/06540.jpg
# Processing image 6541 of 8041
# Saved /tmp/boundedTest/06541.jpg
# Saved /tmp/processedTest/Spyker C8 Coupe 2009/06541.jpg
# Processing image 6542 of 8041
# Saved /tmp/boundedTest/06542.jpg
# Saved /tmp/processedTest/Suzuki SX4 Sedan 2012/06542.jpg
# Processing image 6543 of 8041
# Saved /tmp/boundedTest/06543.jpg
# Saved /tmp/processedTest/Mercedes-Benz S-Class Sedan 2012/06543.jpg
# Processing image 6544 of 8041
# Saved /tmp/boundedTest/06544.jpg
# Saved /tmp/processedTest/BMW 3 Series Sedan 2012/06544.jpg
# Processing image 6545 of 8041
# Saved /tmp/boundedTest/06545.jpg
# Saved /tmp/processedTest/Chrysler PT Cruiser Convertible 2008/06545.jpg
# Processing image 6546 of 8041
# Saved /tmp/boundedTest/06546.jpg
# Saved /tmp/processedTest/Chevrolet Corvette Ron Fellows Edition Z06 2007/06546.jpg
# Processing image 6547 of 8041
# Saved /tmp/boundedTest/06547.jpg
# Saved /tmp/processedTest/Ford Focus Sedan 2007/06547.jpg
# Processing image 6548 of 8041
# Saved /tmp/boundedTest/06548.jpg
# Saved /tmp/processedTest/Isuzu Ascender SUV 2008/06548.jpg
# Processing image 6549 of 8041
# Saved /tmp/boundedTest/06549.jpg
# Saved /tmp/processedTest/HUMMER H2 SUT Crew Cab 2009/06549.jpg
# Processing image 6550 of 8041
# Saved /tmp/boundedTest/06550.jpg
# Saved /tmp/processedTest/Dodge Challenger SRT8 2011/06550.jpg
# Processing image 6551 of 8041
# Saved /tmp/boundedTest/06551.jpg
# Saved /tmp/processedTest/Dodge Ram Pickup 3500 Crew Cab 2010/06551.jpg
# Processing image 6552 of 8041
# Saved /tmp/boundedTest/06552.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/06552.jpg
# Processing image 6553 of 8041
# Saved /tmp/boundedTest/06553.jpg
# Saved /tmp/processedTest/Audi 100 Wagon 1994/06553.jpg
# Processing image 6554 of 8041
# Saved /tmp/boundedTest/06554.jpg
# Saved /tmp/processedTest/Jeep Compass SUV 2012/06554.jpg
# Processing image 6555 of 8041
# Saved /tmp/boundedTest/06555.jpg
# Saved /tmp/processedTest/Acura TL Sedan 2012/06555.jpg
# Processing image 6556 of 8041
# Saved /tmp/boundedTest/06556.jpg
# Saved /tmp/processedTest/Chrysler 300 SRT-8 2010/06556.jpg
# Processing image 6557 of 8041
# Saved /tmp/boundedTest/06557.jpg
# Saved /tmp/processedTest/Buick Regal GS 2012/06557.jpg
# Processing image 6558 of 8041
# Saved /tmp/boundedTest/06558.jpg
# Saved /tmp/processedTest/Tesla Model S Sedan 2012/06558.jpg
# Processing image 6559 of 8041
# Saved /tmp/boundedTest/06559.jpg
# Saved /tmp/processedTest/Rolls-Royce Phantom Sedan 2012/06559.jpg
# Processing image 6560 of 8041
# Saved /tmp/boundedTest/06560.jpg
# Saved /tmp/processedTest/Audi RS 4 Convertible 2008/06560.jpg
# Processing image 6561 of 8041
# Saved /tmp/boundedTest/06561.jpg
# Saved /tmp/processedTest/Bentley Mulsanne Sedan 2011/06561.jpg
# Processing image 6562 of 8041
# Saved /tmp/boundedTest/06562.jpg
# Saved /tmp/processedTest/Ford Freestar Minivan 2007/06562.jpg
# Processing image 6563 of 8041
# Saved /tmp/boundedTest/06563.jpg
# Saved /tmp/processedTest/Ford F-450 Super Duty Crew Cab 2012/06563.jpg
# Processing image 6564 of 8041
# Saved /tmp/boundedTest/06564.jpg
# Saved /tmp/processedTest/Acura TSX Sedan 2012/06564.jpg
# Processing image 6565 of 8041
# Saved /tmp/boundedTest/06565.jpg
# Saved /tmp/processedTest/Chevrolet TrailBlazer SS 2009/06565.jpg
# Processing image 6566 of 8041
# Saved /tmp/boundedTest/06566.jpg
# Saved /tmp/processedTest/Dodge Dakota Club Cab 2007/06566.jpg
# Processing image 6567 of 8041
# Saved /tmp/boundedTest/06567.jpg
# Saved /tmp/processedTest/Mitsubishi Lancer Sedan 2012/06567.jpg
# Processing image 6568 of 8041
# Saved /tmp/boundedTest/06568.jpg
# Saved /tmp/processedTest/Audi S5 Convertible 2012/06568.jpg
# Processing image 6569 of 8041
# Saved /tmp/boundedTest/06569.jpg
# Saved /tmp/processedTest/Ford Mustang Convertible 2007/06569.jpg
# Processing image 6570 of 8041
# Saved /tmp/boundedTest/06570.jpg
# Saved /tmp/processedTest/Mazda Tribute SUV 2011/06570.jpg
# Processing image 6571 of 8041
# Saved /tmp/boundedTest/06571.jpg
# Saved /tmp/processedTest/McLaren MP4-12C Coupe 2012/06571.jpg
# Processing image 6572 of 8041
# Saved /tmp/boundedTest/06572.jpg
# Saved /tmp/processedTest/Chevrolet Express Van 2007/06572.jpg
# Processing image 6573 of 8041
# Saved /tmp/boundedTest/06573.jpg
# Saved /tmp/processedTest/Ford Edge SUV 2012/06573.jpg
# Processing image 6574 of 8041
# Saved /tmp/boundedTest/06574.jpg
# Saved /tmp/processedTest/Honda Odyssey Minivan 2007/06574.jpg
# Processing image 6575 of 8041
# Saved /tmp/boundedTest/06575.jpg
# Saved /tmp/processedTest/BMW 1 Series Coupe 2012/06575.jpg
# Processing image 6576 of 8041
# Saved /tmp/boundedTest/06576.jpg
# Saved /tmp/processedTest/Bugatti Veyron 16.4 Coupe 2009/06576.jpg
# Processing image 6577 of 8041
# Saved /tmp/boundedTest/06577.jpg
# Saved /tmp/processedTest/Acura TL Sedan 2012/06577.jpg
# Processing image 6578 of 8041
# Saved /tmp/boundedTest/06578.jpg
# Saved /tmp/processedTest/Hyundai Veracruz SUV 2012/06578.jpg
# Processing image 6579 of 8041
# Saved /tmp/boundedTest/06579.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Classic Extended Cab 2007/06579.jpg
# Processing image 6580 of 8041
# Saved /tmp/boundedTest/06580.jpg
# Saved /tmp/processedTest/Dodge Journey SUV 2012/06580.jpg
# Processing image 6581 of 8041
# Saved /tmp/boundedTest/06581.jpg
# Saved /tmp/processedTest/Dodge Sprinter Cargo Van 2009/06581.jpg
# Processing image 6582 of 8041
# Saved /tmp/boundedTest/06582.jpg
# Saved /tmp/processedTest/BMW 3 Series Sedan 2012/06582.jpg
# Processing image 6583 of 8041
# Saved /tmp/boundedTest/06583.jpg
# Saved /tmp/processedTest/Bentley Arnage Sedan 2009/06583.jpg
# Processing image 6584 of 8041
# Saved /tmp/boundedTest/06584.jpg
# Saved /tmp/processedTest/Ford Focus Sedan 2007/06584.jpg
# Processing image 6585 of 8041
# Saved /tmp/boundedTest/06585.jpg
# Saved /tmp/processedTest/BMW M5 Sedan 2010/06585.jpg
# Processing image 6586 of 8041
# Saved /tmp/boundedTest/06586.jpg
# Saved /tmp/processedTest/Chevrolet Express Van 2007/06586.jpg
# Processing image 6587 of 8041
# Saved /tmp/boundedTest/06587.jpg
# Saved /tmp/processedTest/Dodge Caliber Wagon 2007/06587.jpg
# Processing image 6588 of 8041
# Saved /tmp/boundedTest/06588.jpg
# Saved /tmp/processedTest/Audi TT RS Coupe 2012/06588.jpg
# Processing image 6589 of 8041
# Saved /tmp/boundedTest/06589.jpg
# Saved /tmp/processedTest/Bentley Mulsanne Sedan 2011/06589.jpg
# Processing image 6590 of 8041
# Saved /tmp/boundedTest/06590.jpg
# Saved /tmp/processedTest/Jeep Patriot SUV 2012/06590.jpg
# Processing image 6591 of 8041
# Saved /tmp/boundedTest/06591.jpg
# Saved /tmp/processedTest/Chevrolet Corvette ZR1 2012/06591.jpg
# Processing image 6592 of 8041
# Saved /tmp/boundedTest/06592.jpg
# Saved /tmp/processedTest/Toyota 4Runner SUV 2012/06592.jpg
# Processing image 6593 of 8041
# Saved /tmp/boundedTest/06593.jpg
# Saved /tmp/processedTest/Chevrolet Traverse SUV 2012/06593.jpg
# Processing image 6594 of 8041
# Saved /tmp/boundedTest/06594.jpg
# Saved /tmp/processedTest/Chevrolet HHR SS 2010/06594.jpg
# Processing image 6595 of 8041
# Saved /tmp/boundedTest/06595.jpg
# Saved /tmp/processedTest/BMW 3 Series Sedan 2012/06595.jpg
# Processing image 6596 of 8041
# Saved /tmp/boundedTest/06596.jpg
# Saved /tmp/processedTest/Volkswagen Golf Hatchback 2012/06596.jpg
# Processing image 6597 of 8041
# Saved /tmp/boundedTest/06597.jpg
# Saved /tmp/processedTest/Bugatti Veyron 16.4 Coupe 2009/06597.jpg
# Processing image 6598 of 8041
# Saved /tmp/boundedTest/06598.jpg
# Saved /tmp/processedTest/Dodge Durango SUV 2007/06598.jpg
# Processing image 6599 of 8041
# Saved /tmp/boundedTest/06599.jpg
# Saved /tmp/processedTest/Volvo C30 Hatchback 2012/06599.jpg
# Processing image 6600 of 8041
# Saved /tmp/boundedTest/06600.jpg
# Saved /tmp/processedTest/Jeep Wrangler SUV 2012/06600.jpg
# Processing image 6601 of 8041
# Saved /tmp/boundedTest/06601.jpg
# Saved /tmp/processedTest/Audi S4 Sedan 2007/06601.jpg
# Processing image 6602 of 8041
# Saved /tmp/boundedTest/06602.jpg
# Saved /tmp/processedTest/Chrysler 300 SRT-8 2010/06602.jpg
# Processing image 6603 of 8041
# Saved /tmp/boundedTest/06603.jpg
# Saved /tmp/processedTest/Dodge Charger SRT-8 2009/06603.jpg
# Processing image 6604 of 8041
# Saved /tmp/boundedTest/06604.jpg
# Saved /tmp/processedTest/Dodge Caliber Wagon 2007/06604.jpg
# Processing image 6605 of 8041
# Saved /tmp/boundedTest/06605.jpg
# Saved /tmp/processedTest/Chrysler PT Cruiser Convertible 2008/06605.jpg
# Processing image 6606 of 8041
# Saved /tmp/boundedTest/06606.jpg
# Saved /tmp/processedTest/Lamborghini Aventador Coupe 2012/06606.jpg
# Processing image 6607 of 8041
# Saved /tmp/boundedTest/06607.jpg
# Saved /tmp/processedTest/Rolls-Royce Phantom Drophead Coupe Convertible 2012/06607.jpg
# Processing image 6608 of 8041
# Saved /tmp/boundedTest/06608.jpg
# Saved /tmp/processedTest/Ford Freestar Minivan 2007/06608.jpg
# Processing image 6609 of 8041
# Saved /tmp/boundedTest/06609.jpg
# Saved /tmp/processedTest/Hyundai Elantra Sedan 2007/06609.jpg
# Processing image 6610 of 8041
# Saved /tmp/boundedTest/06610.jpg
# Saved /tmp/processedTest/Audi 100 Wagon 1994/06610.jpg
# Processing image 6611 of 8041
# Saved /tmp/boundedTest/06611.jpg
# Saved /tmp/processedTest/Mitsubishi Lancer Sedan 2012/06611.jpg
# Processing image 6612 of 8041
# Saved /tmp/boundedTest/06612.jpg
# Saved /tmp/processedTest/Rolls-Royce Phantom Sedan 2012/06612.jpg
# Processing image 6613 of 8041
# Saved /tmp/boundedTest/06613.jpg
# Saved /tmp/processedTest/Volkswagen Beetle Hatchback 2012/06613.jpg
# Processing image 6614 of 8041
# Saved /tmp/boundedTest/06614.jpg
# Saved /tmp/processedTest/Scion xD Hatchback 2012/06614.jpg
# Processing image 6615 of 8041
# Saved /tmp/boundedTest/06615.jpg
# Saved /tmp/processedTest/smart fortwo Convertible 2012/06615.jpg
# Processing image 6616 of 8041
# Saved /tmp/boundedTest/06616.jpg
# Saved /tmp/processedTest/MINI Cooper Roadster Convertible 2012/06616.jpg
# Processing image 6617 of 8041
# Saved /tmp/boundedTest/06617.jpg
# Saved /tmp/processedTest/Jaguar XK XKR 2012/06617.jpg
# Processing image 6618 of 8041
# Saved /tmp/boundedTest/06618.jpg
# Saved /tmp/processedTest/Volkswagen Golf Hatchback 1991/06618.jpg
# Processing image 6619 of 8041
# Saved /tmp/boundedTest/06619.jpg
# Saved /tmp/processedTest/Mercedes-Benz E-Class Sedan 2012/06619.jpg
# Processing image 6620 of 8041
# Saved /tmp/boundedTest/06620.jpg
# Saved /tmp/processedTest/Suzuki Aerio Sedan 2007/06620.jpg
# Processing image 6621 of 8041
# Saved /tmp/boundedTest/06621.jpg
# Saved /tmp/processedTest/BMW 3 Series Wagon 2012/06621.jpg
# Processing image 6622 of 8041
# Saved /tmp/boundedTest/06622.jpg
# Saved /tmp/processedTest/Nissan 240SX Coupe 1998/06622.jpg
# Processing image 6623 of 8041
# Saved /tmp/boundedTest/06623.jpg
# Saved /tmp/processedTest/Buick Regal GS 2012/06623.jpg
# Processing image 6624 of 8041
# Saved /tmp/boundedTest/06624.jpg
# Saved /tmp/processedTest/Jeep Wrangler SUV 2012/06624.jpg
# Processing image 6625 of 8041
# Saved /tmp/boundedTest/06625.jpg
# Saved /tmp/processedTest/Ram C/V Cargo Van Minivan 2012/06625.jpg
# Processing image 6626 of 8041
# Saved /tmp/boundedTest/06626.jpg
# Saved /tmp/processedTest/BMW X5 SUV 2007/06626.jpg
# Processing image 6627 of 8041
# Saved /tmp/boundedTest/06627.jpg
# Saved /tmp/processedTest/Lamborghini Gallardo LP 570-4 Superleggera 2012/06627.jpg
# Processing image 6628 of 8041
# Saved /tmp/boundedTest/06628.jpg
# Saved /tmp/processedTest/Jeep Liberty SUV 2012/06628.jpg
# Processing image 6629 of 8041
# Saved /tmp/boundedTest/06629.jpg
# Saved /tmp/processedTest/Toyota Corolla Sedan 2012/06629.jpg
# Processing image 6630 of 8041
# Saved /tmp/boundedTest/06630.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/06630.jpg
# Processing image 6631 of 8041
# Saved /tmp/boundedTest/06631.jpg
# Saved /tmp/processedTest/Audi S5 Convertible 2012/06631.jpg
# Processing image 6632 of 8041
# Saved /tmp/boundedTest/06632.jpg
# Saved /tmp/processedTest/Dodge Dakota Club Cab 2007/06632.jpg
# Processing image 6633 of 8041
# Saved /tmp/boundedTest/06633.jpg
# Saved /tmp/processedTest/Chevrolet Cobalt SS 2010/06633.jpg
# Processing image 6634 of 8041
# Saved /tmp/boundedTest/06634.jpg
# Saved /tmp/processedTest/Infiniti G Coupe IPL 2012/06634.jpg
# Processing image 6635 of 8041
# Saved /tmp/boundedTest/06635.jpg
# Saved /tmp/processedTest/Hyundai Sonata Hybrid Sedan 2012/06635.jpg
# Processing image 6636 of 8041
# Saved /tmp/boundedTest/06636.jpg
# Saved /tmp/processedTest/Jaguar XK XKR 2012/06636.jpg
# Processing image 6637 of 8041
# Saved /tmp/boundedTest/06637.jpg
# Saved /tmp/processedTest/Cadillac SRX SUV 2012/06637.jpg
# Processing image 6638 of 8041
# Saved /tmp/boundedTest/06638.jpg
# Saved /tmp/processedTest/Audi S4 Sedan 2012/06638.jpg
# Processing image 6639 of 8041
# Saved /tmp/boundedTest/06639.jpg
# Saved /tmp/processedTest/Chevrolet Cobalt SS 2010/06639.jpg
# Processing image 6640 of 8041
# Saved /tmp/boundedTest/06640.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Regular Cab 2012/06640.jpg
# Processing image 6641 of 8041
# Saved /tmp/boundedTest/06641.jpg
# Saved /tmp/processedTest/Bentley Continental Supersports Conv. Convertible 2012/06641.jpg
# Processing image 6642 of 8041
# Saved /tmp/boundedTest/06642.jpg
# Saved /tmp/processedTest/Spyker C8 Convertible 2009/06642.jpg
# Processing image 6643 of 8041
# Saved /tmp/boundedTest/06643.jpg
# Saved /tmp/processedTest/Chevrolet Malibu Hybrid Sedan 2010/06643.jpg
# Processing image 6644 of 8041
# Saved /tmp/boundedTest/06644.jpg
# Saved /tmp/processedTest/Fisker Karma Sedan 2012/06644.jpg
# Processing image 6645 of 8041
# Saved /tmp/boundedTest/06645.jpg
# Saved /tmp/processedTest/Rolls-Royce Phantom Drophead Coupe Convertible 2012/06645.jpg
# Processing image 6646 of 8041
# Saved /tmp/boundedTest/06646.jpg
# Saved /tmp/processedTest/BMW M3 Coupe 2012/06646.jpg
# Processing image 6647 of 8041
# Saved /tmp/boundedTest/06647.jpg
# Saved /tmp/processedTest/BMW 6 Series Convertible 2007/06647.jpg
# Processing image 6648 of 8041
# Saved /tmp/boundedTest/06648.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 2500HD Regular Cab 2012/06648.jpg
# Processing image 6649 of 8041
# Saved /tmp/boundedTest/06649.jpg
# Saved /tmp/processedTest/Chevrolet TrailBlazer SS 2009/06649.jpg
# Processing image 6650 of 8041
# Saved /tmp/boundedTest/06650.jpg
# Saved /tmp/processedTest/Ford F-150 Regular Cab 2012/06650.jpg
# Processing image 6651 of 8041
# Saved /tmp/boundedTest/06651.jpg
# Saved /tmp/processedTest/Hyundai Tucson SUV 2012/06651.jpg
# Processing image 6652 of 8041
# Saved /tmp/boundedTest/06652.jpg
# Saved /tmp/processedTest/Hyundai Veloster Hatchback 2012/06652.jpg
# Processing image 6653 of 8041
# Saved /tmp/boundedTest/06653.jpg
# Saved /tmp/processedTest/GMC Acadia SUV 2012/06653.jpg
# Processing image 6654 of 8041
# Saved /tmp/boundedTest/06654.jpg
# Saved /tmp/processedTest/Chevrolet Malibu Sedan 2007/06654.jpg
# Processing image 6655 of 8041
# Saved /tmp/boundedTest/06655.jpg
# Saved /tmp/processedTest/BMW M6 Convertible 2010/06655.jpg
# Processing image 6656 of 8041
# Saved /tmp/boundedTest/06656.jpg
# Saved /tmp/processedTest/Volvo XC90 SUV 2007/06656.jpg
# Processing image 6657 of 8041
# Saved /tmp/boundedTest/06657.jpg
# Saved /tmp/processedTest/Cadillac CTS-V Sedan 2012/06657.jpg
# Processing image 6658 of 8041
# Saved /tmp/boundedTest/06658.jpg
# Saved /tmp/processedTest/Dodge Charger SRT-8 2009/06658.jpg
# Processing image 6659 of 8041
# Saved /tmp/boundedTest/06659.jpg
# Saved /tmp/processedTest/McLaren MP4-12C Coupe 2012/06659.jpg
# Processing image 6660 of 8041
# Saved /tmp/boundedTest/06660.jpg
# Saved /tmp/processedTest/Chevrolet Corvette ZR1 2012/06660.jpg
# Processing image 6661 of 8041
# Saved /tmp/boundedTest/06661.jpg
# Saved /tmp/processedTest/Ford Mustang Convertible 2007/06661.jpg
# Processing image 6662 of 8041
# Saved /tmp/boundedTest/06662.jpg
# Saved /tmp/processedTest/Infiniti G Coupe IPL 2012/06662.jpg
# Processing image 6663 of 8041
# Saved /tmp/boundedTest/06663.jpg
# Saved /tmp/processedTest/Bentley Arnage Sedan 2009/06663.jpg
# Processing image 6664 of 8041
# Saved /tmp/boundedTest/06664.jpg
# Saved /tmp/processedTest/Chevrolet Malibu Hybrid Sedan 2010/06664.jpg
# Processing image 6665 of 8041
# Saved /tmp/boundedTest/06665.jpg
# Saved /tmp/processedTest/HUMMER H3T Crew Cab 2010/06665.jpg
# Processing image 6666 of 8041
# Saved /tmp/boundedTest/06666.jpg
# Saved /tmp/processedTest/Cadillac SRX SUV 2012/06666.jpg
# Processing image 6667 of 8041
# Saved /tmp/boundedTest/06667.jpg
# Saved /tmp/processedTest/Porsche Panamera Sedan 2012/06667.jpg
# Processing image 6668 of 8041
# Saved /tmp/boundedTest/06668.jpg
# Saved /tmp/processedTest/Audi TT RS Coupe 2012/06668.jpg
# Processing image 6669 of 8041
# Saved /tmp/boundedTest/06669.jpg
# Saved /tmp/processedTest/Chevrolet Avalanche Crew Cab 2012/06669.jpg
# Processing image 6670 of 8041
# Saved /tmp/boundedTest/06670.jpg
# Saved /tmp/processedTest/Volvo 240 Sedan 1993/06670.jpg
# Processing image 6671 of 8041
# Saved /tmp/boundedTest/06671.jpg
# Saved /tmp/processedTest/Toyota Camry Sedan 2012/06671.jpg
# Processing image 6672 of 8041
# Saved /tmp/boundedTest/06672.jpg
# Saved /tmp/processedTest/Dodge Ram Pickup 3500 Crew Cab 2010/06672.jpg
# Processing image 6673 of 8041
# Saved /tmp/boundedTest/06673.jpg
# Saved /tmp/processedTest/Honda Odyssey Minivan 2012/06673.jpg
# Processing image 6674 of 8041
# Saved /tmp/boundedTest/06674.jpg
# Saved /tmp/processedTest/Ford Edge SUV 2012/06674.jpg
# Processing image 6675 of 8041
# Saved /tmp/boundedTest/06675.jpg
# Saved /tmp/processedTest/Chevrolet Express Cargo Van 2007/06675.jpg
# Processing image 6676 of 8041
# Saved /tmp/boundedTest/06676.jpg
# Saved /tmp/processedTest/Audi 100 Wagon 1994/06676.jpg
# Processing image 6677 of 8041
# Saved /tmp/boundedTest/06677.jpg
# Saved /tmp/processedTest/Ford Ranger SuperCab 2011/06677.jpg
# Processing image 6678 of 8041
# Saved /tmp/boundedTest/06678.jpg
# Saved /tmp/processedTest/Hyundai Sonata Sedan 2012/06678.jpg
# Processing image 6679 of 8041
# Saved /tmp/boundedTest/06679.jpg
# Saved /tmp/processedTest/Bentley Continental GT Coupe 2012/06679.jpg
# Processing image 6680 of 8041
# Saved /tmp/boundedTest/06680.jpg
# Saved /tmp/processedTest/Chrysler PT Cruiser Convertible 2008/06680.jpg
# Processing image 6681 of 8041
# Saved /tmp/boundedTest/06681.jpg
# Saved /tmp/processedTest/Audi S4 Sedan 2012/06681.jpg
# Processing image 6682 of 8041
# Saved /tmp/boundedTest/06682.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Extended Cab 2012/06682.jpg
# Processing image 6683 of 8041
# Saved /tmp/boundedTest/06683.jpg
# Saved /tmp/processedTest/Porsche Panamera Sedan 2012/06683.jpg
# Processing image 6684 of 8041
# Saved /tmp/boundedTest/06684.jpg
# Saved /tmp/processedTest/Isuzu Ascender SUV 2008/06684.jpg
# Processing image 6685 of 8041
# Saved /tmp/boundedTest/06685.jpg
# Saved /tmp/processedTest/Suzuki Kizashi Sedan 2012/06685.jpg
# Processing image 6686 of 8041
# Saved /tmp/boundedTest/06686.jpg
# Saved /tmp/processedTest/GMC Savana Van 2012/06686.jpg
# Processing image 6687 of 8041
# Saved /tmp/boundedTest/06687.jpg
# Saved /tmp/processedTest/Chevrolet Camaro Convertible 2012/06687.jpg
# Processing image 6688 of 8041
# Saved /tmp/boundedTest/06688.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 2500HD Regular Cab 2012/06688.jpg
# Processing image 6689 of 8041
# Saved /tmp/boundedTest/06689.jpg
# Saved /tmp/processedTest/Hyundai Sonata Hybrid Sedan 2012/06689.jpg
# Processing image 6690 of 8041
# Saved /tmp/boundedTest/06690.jpg
# Saved /tmp/processedTest/Chrysler PT Cruiser Convertible 2008/06690.jpg
# Processing image 6691 of 8041
# Saved /tmp/boundedTest/06691.jpg
# Saved /tmp/processedTest/Ford F-450 Super Duty Crew Cab 2012/06691.jpg
# Processing image 6692 of 8041
# Saved /tmp/boundedTest/06692.jpg
# Saved /tmp/processedTest/Lamborghini Aventador Coupe 2012/06692.jpg
# Processing image 6693 of 8041
# Saved /tmp/boundedTest/06693.jpg
# Saved /tmp/processedTest/Spyker C8 Coupe 2009/06693.jpg
# Processing image 6694 of 8041
# Saved /tmp/boundedTest/06694.jpg
# Saved /tmp/processedTest/Hyundai Veloster Hatchback 2012/06694.jpg
# Processing image 6695 of 8041
# Saved /tmp/boundedTest/06695.jpg
# Saved /tmp/processedTest/Tesla Model S Sedan 2012/06695.jpg
# Processing image 6696 of 8041
# Saved /tmp/boundedTest/06696.jpg
# Saved /tmp/processedTest/BMW X5 SUV 2007/06696.jpg
# Processing image 6697 of 8041
# Saved /tmp/boundedTest/06697.jpg
# Saved /tmp/processedTest/BMW 1 Series Convertible 2012/06697.jpg
# Processing image 6698 of 8041
# Saved /tmp/boundedTest/06698.jpg
# Saved /tmp/processedTest/Audi S4 Sedan 2007/06698.jpg
# Processing image 6699 of 8041
# Saved /tmp/boundedTest/06699.jpg
# Saved /tmp/processedTest/Audi TTS Coupe 2012/06699.jpg
# Processing image 6700 of 8041
# Saved /tmp/boundedTest/06700.jpg
# Saved /tmp/processedTest/Ford F-150 Regular Cab 2012/06700.jpg
# Processing image 6701 of 8041
# Saved /tmp/boundedTest/06701.jpg
# Saved /tmp/processedTest/Acura Integra Type R 2001/06701.jpg
# Processing image 6702 of 8041
# Saved /tmp/boundedTest/06702.jpg
# Saved /tmp/processedTest/Ford Expedition EL SUV 2009/06702.jpg
# Processing image 6703 of 8041
# Saved /tmp/boundedTest/06703.jpg
# Saved /tmp/processedTest/Dodge Charger Sedan 2012/06703.jpg
# Processing image 6704 of 8041
# Saved /tmp/boundedTest/06704.jpg
# Saved /tmp/processedTest/Spyker C8 Convertible 2009/06704.jpg
# Processing image 6705 of 8041
# Saved /tmp/boundedTest/06705.jpg
# Saved /tmp/processedTest/Toyota 4Runner SUV 2012/06705.jpg
# Processing image 6706 of 8041
# Saved /tmp/boundedTest/06706.jpg
# Saved /tmp/processedTest/GMC Terrain SUV 2012/06706.jpg
# Processing image 6707 of 8041
# Saved /tmp/boundedTest/06707.jpg
# Saved /tmp/processedTest/Lamborghini Diablo Coupe 2001/06707.jpg
# Processing image 6708 of 8041
# Saved /tmp/boundedTest/06708.jpg
# Saved /tmp/processedTest/Dodge Durango SUV 2012/06708.jpg
# Processing image 6709 of 8041
# Saved /tmp/boundedTest/06709.jpg
# Saved /tmp/processedTest/Audi S4 Sedan 2012/06709.jpg
# Processing image 6710 of 8041
# Saved /tmp/boundedTest/06710.jpg
# Saved /tmp/processedTest/Mercedes-Benz 300-Class Convertible 1993/06710.jpg
# Processing image 6711 of 8041
# Saved /tmp/boundedTest/06711.jpg
# Saved /tmp/processedTest/Bentley Mulsanne Sedan 2011/06711.jpg
# Processing image 6712 of 8041
# Saved /tmp/boundedTest/06712.jpg
# Saved /tmp/processedTest/Dodge Caravan Minivan 1997/06712.jpg
# Processing image 6713 of 8041
# Saved /tmp/boundedTest/06713.jpg
# Saved /tmp/processedTest/Hyundai Accent Sedan 2012/06713.jpg
# Processing image 6714 of 8041
# Saved /tmp/boundedTest/06714.jpg
# Saved /tmp/processedTest/HUMMER H3T Crew Cab 2010/06714.jpg
# Processing image 6715 of 8041
# Saved /tmp/boundedTest/06715.jpg
# Saved /tmp/processedTest/Dodge Dakota Club Cab 2007/06715.jpg
# Processing image 6716 of 8041
# Saved /tmp/boundedTest/06716.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/06716.jpg
# Processing image 6717 of 8041
# Saved /tmp/boundedTest/06717.jpg
# Saved /tmp/processedTest/Acura Integra Type R 2001/06717.jpg
# Processing image 6718 of 8041
# Saved /tmp/boundedTest/06718.jpg
# Saved /tmp/processedTest/GMC Savana Van 2012/06718.jpg
# Processing image 6719 of 8041
# Saved /tmp/boundedTest/06719.jpg
# Saved /tmp/processedTest/Ford Focus Sedan 2007/06719.jpg
# Processing image 6720 of 8041
# Saved /tmp/boundedTest/06720.jpg
# Saved /tmp/processedTest/BMW 3 Series Sedan 2012/06720.jpg
# Processing image 6721 of 8041
# Saved /tmp/boundedTest/06721.jpg
# Saved /tmp/processedTest/HUMMER H3T Crew Cab 2010/06721.jpg
# Processing image 6722 of 8041
# Saved /tmp/boundedTest/06722.jpg
# Saved /tmp/processedTest/Aston Martin Virage Convertible 2012/06722.jpg
# Processing image 6723 of 8041
# Saved /tmp/boundedTest/06723.jpg
# Saved /tmp/processedTest/Hyundai Azera Sedan 2012/06723.jpg
# Processing image 6724 of 8041
# Saved /tmp/boundedTest/06724.jpg
# Saved /tmp/processedTest/Audi S5 Coupe 2012/06724.jpg
# Processing image 6725 of 8041
# Saved /tmp/boundedTest/06725.jpg
# Saved /tmp/processedTest/Chevrolet Impala Sedan 2007/06725.jpg
# Processing image 6726 of 8041
# Saved /tmp/boundedTest/06726.jpg
# Saved /tmp/processedTest/Audi S6 Sedan 2011/06726.jpg
# Processing image 6727 of 8041
# Saved /tmp/boundedTest/06727.jpg
# Saved /tmp/processedTest/MINI Cooper Roadster Convertible 2012/06727.jpg
# Processing image 6728 of 8041
# Saved /tmp/boundedTest/06728.jpg
# Saved /tmp/processedTest/Chevrolet Traverse SUV 2012/06728.jpg
# Processing image 6729 of 8041
# Saved /tmp/boundedTest/06729.jpg
# Saved /tmp/processedTest/Audi TTS Coupe 2012/06729.jpg
# Processing image 6730 of 8041
# Saved /tmp/boundedTest/06730.jpg
# Saved /tmp/processedTest/Jaguar XK XKR 2012/06730.jpg
# Processing image 6731 of 8041
# Saved /tmp/boundedTest/06731.jpg
# Saved /tmp/processedTest/Scion xD Hatchback 2012/06731.jpg
# Processing image 6732 of 8041
# Saved /tmp/boundedTest/06732.jpg
# Saved /tmp/processedTest/Hyundai Accent Sedan 2012/06732.jpg
# Processing image 6733 of 8041
# Saved /tmp/boundedTest/06733.jpg
# Saved /tmp/processedTest/Dodge Dakota Crew Cab 2010/06733.jpg
# Processing image 6734 of 8041
# Saved /tmp/boundedTest/06734.jpg
# Saved /tmp/processedTest/Eagle Talon Hatchback 1998/06734.jpg
# Processing image 6735 of 8041
# Saved /tmp/boundedTest/06735.jpg
# Saved /tmp/processedTest/Audi S5 Convertible 2012/06735.jpg
# Processing image 6736 of 8041
# Saved /tmp/boundedTest/06736.jpg
# Saved /tmp/processedTest/Chrysler PT Cruiser Convertible 2008/06736.jpg
# Processing image 6737 of 8041
# Saved /tmp/boundedTest/06737.jpg
# Saved /tmp/processedTest/Maybach Landaulet Convertible 2012/06737.jpg
# Processing image 6738 of 8041
# Saved /tmp/boundedTest/06738.jpg
# Saved /tmp/processedTest/Infiniti QX56 SUV 2011/06738.jpg
# Processing image 6739 of 8041
# Saved /tmp/boundedTest/06739.jpg
# Saved /tmp/processedTest/GMC Terrain SUV 2012/06739.jpg
# Processing image 6740 of 8041
# Saved /tmp/boundedTest/06740.jpg
# Saved /tmp/processedTest/GMC Savana Van 2012/06740.jpg
# Processing image 6741 of 8041
# Saved /tmp/boundedTest/06741.jpg
# Saved /tmp/processedTest/Buick Rainier SUV 2007/06741.jpg
# Processing image 6742 of 8041
# Saved /tmp/boundedTest/06742.jpg
# Saved /tmp/processedTest/Chevrolet Avalanche Crew Cab 2012/06742.jpg
# Processing image 6743 of 8041
# Saved /tmp/boundedTest/06743.jpg
# Saved /tmp/processedTest/Chrysler Crossfire Convertible 2008/06743.jpg
# Processing image 6744 of 8041
# Saved /tmp/boundedTest/06744.jpg
# Saved /tmp/processedTest/Chrysler Town and Country Minivan 2012/06744.jpg
# Processing image 6745 of 8041
# Saved /tmp/boundedTest/06745.jpg
# Saved /tmp/processedTest/Toyota 4Runner SUV 2012/06745.jpg
# Processing image 6746 of 8041
# Saved /tmp/boundedTest/06746.jpg
# Saved /tmp/processedTest/Lamborghini Diablo Coupe 2001/06746.jpg
# Processing image 6747 of 8041
# Saved /tmp/boundedTest/06747.jpg
# Saved /tmp/processedTest/Jeep Wrangler SUV 2012/06747.jpg
# Processing image 6748 of 8041
# Saved /tmp/boundedTest/06748.jpg
# Saved /tmp/processedTest/Rolls-Royce Phantom Drophead Coupe Convertible 2012/06748.jpg
# Processing image 6749 of 8041
# Saved /tmp/boundedTest/06749.jpg
# Saved /tmp/processedTest/Jaguar XK XKR 2012/06749.jpg
# Processing image 6750 of 8041
# Saved /tmp/boundedTest/06750.jpg
# Saved /tmp/processedTest/Audi TTS Coupe 2012/06750.jpg
# Processing image 6751 of 8041
# Saved /tmp/boundedTest/06751.jpg
# Saved /tmp/processedTest/Chrysler Crossfire Convertible 2008/06751.jpg
# Processing image 6752 of 8041
# Saved /tmp/boundedTest/06752.jpg
# Saved /tmp/processedTest/Bentley Continental GT Coupe 2012/06752.jpg
# Processing image 6753 of 8041
# Saved /tmp/boundedTest/06753.jpg
# Saved /tmp/processedTest/Ferrari 458 Italia Coupe 2012/06753.jpg
# Processing image 6754 of 8041
# Saved /tmp/boundedTest/06754.jpg
# Saved /tmp/processedTest/Chevrolet Avalanche Crew Cab 2012/06754.jpg
# Processing image 6755 of 8041
# Saved /tmp/boundedTest/06755.jpg
# Saved /tmp/processedTest/Buick Enclave SUV 2012/06755.jpg
# Processing image 6756 of 8041
# Saved /tmp/boundedTest/06756.jpg
# ...
# Processing image 7914 of 8041
# Saved /tmp/boundedTest/07914.jpg
# Saved /tmp/processedTest/Dodge Challenger SRT8 2011/07914.jpg
# Processing image 7915 of 8041
# Saved /tmp/boundedTest/07915.jpg
# Saved /tmp/processedTest/Audi V8 Sedan 1994/07915.jpg
# Processing image 7916 of 8041
# Saved /tmp/boundedTest/07916.jpg
# Saved /tmp/processedTest/Mitsubishi Lancer Sedan 2012/07916.jpg
# Processing image 7917 of 8041
# Saved /tmp/boundedTest/07917.jpg
# Saved /tmp/processedTest/AM General Hummer SUV 2000/07917.jpg
# Processing image 7918 of 8041
# Saved /tmp/boundedTest/07918.jpg
# Saved /tmp/processedTest/Toyota Corolla Sedan 2012/07918.jpg
# Processing image 7919 of 8041
# Saved /tmp/boundedTest/07919.jpg
# Saved /tmp/processedTest/Ford Focus Sedan 2007/07919.jpg
# Processing image 7920 of 8041
# Saved /tmp/boundedTest/07920.jpg
# Saved /tmp/processedTest/Spyker C8 Convertible 2009/07920.jpg
# Processing image 7921 of 8041
# Saved /tmp/boundedTest/07921.jpg
# Saved /tmp/processedTest/Volvo C30 Hatchback 2012/07921.jpg
# Processing image 7922 of 8041
# Saved /tmp/boundedTest/07922.jpg
# Saved /tmp/processedTest/Ford Freestar Minivan 2007/07922.jpg
# Processing image 7923 of 8041
# Saved /tmp/boundedTest/07923.jpg
# Saved /tmp/processedTest/Suzuki Kizashi Sedan 2012/07923.jpg
# Processing image 7924 of 8041
# Saved /tmp/boundedTest/07924.jpg
# Saved /tmp/processedTest/Cadillac Escalade EXT Crew Cab 2007/07924.jpg
# Processing image 7925 of 8041
# Saved /tmp/boundedTest/07925.jpg
# Saved /tmp/processedTest/BMW M3 Coupe 2012/07925.jpg
# Processing image 7926 of 8041
# Saved /tmp/boundedTest/07926.jpg
# Saved /tmp/processedTest/Dodge Journey SUV 2012/07926.jpg
# Processing image 7927 of 8041
# Saved /tmp/boundedTest/07927.jpg
# Saved /tmp/processedTest/HUMMER H3T Crew Cab 2010/07927.jpg
# Processing image 7928 of 8041
# Saved /tmp/boundedTest/07928.jpg
# Saved /tmp/processedTest/BMW X5 SUV 2007/07928.jpg
# Processing image 7929 of 8041
# Saved /tmp/boundedTest/07929.jpg
# Saved /tmp/processedTest/Chevrolet Sonic Sedan 2012/07929.jpg
# Processing image 7930 of 8041
# Saved /tmp/boundedTest/07930.jpg
# Saved /tmp/processedTest/HUMMER H2 SUT Crew Cab 2009/07930.jpg
# Processing image 7931 of 8041
# Saved /tmp/boundedTest/07931.jpg
# Saved /tmp/processedTest/Volvo XC90 SUV 2007/07931.jpg
# Processing image 7932 of 8041
# Saved /tmp/boundedTest/07932.jpg
# Saved /tmp/processedTest/Eagle Talon Hatchback 1998/07932.jpg
# Processing image 7933 of 8041
# Saved /tmp/boundedTest/07933.jpg
# Saved /tmp/processedTest/Bugatti Veyron 16.4 Convertible 2009/07933.jpg
# Processing image 7934 of 8041
# Saved /tmp/boundedTest/07934.jpg
# Saved /tmp/processedTest/Infiniti QX56 SUV 2011/07934.jpg
# Processing image 7935 of 8041
# Saved /tmp/boundedTest/07935.jpg
# Saved /tmp/processedTest/Chevrolet Tahoe Hybrid SUV 2012/07935.jpg
# Processing image 7936 of 8041
# Saved /tmp/boundedTest/07936.jpg
# Saved /tmp/processedTest/Mercedes-Benz E-Class Sedan 2012/07936.jpg
# Processing image 7937 of 8041
# Saved /tmp/boundedTest/07937.jpg
# Saved /tmp/processedTest/Audi S6 Sedan 2011/07937.jpg
# Processing image 7938 of 8041
# Saved /tmp/boundedTest/07938.jpg
# Saved /tmp/processedTest/BMW X5 SUV 2007/07938.jpg
# Processing image 7939 of 8041
# Saved /tmp/boundedTest/07939.jpg
# Saved /tmp/processedTest/Eagle Talon Hatchback 1998/07939.jpg
# Processing image 7940 of 8041
# Saved /tmp/boundedTest/07940.jpg
# Saved /tmp/processedTest/Aston Martin V8 Vantage Coupe 2012/07940.jpg
# Processing image 7941 of 8041
# Saved /tmp/boundedTest/07941.jpg
# Saved /tmp/processedTest/Buick Rainier SUV 2007/07941.jpg
# Processing image 7942 of 8041
# Saved /tmp/boundedTest/07942.jpg
# Saved /tmp/processedTest/Nissan Leaf Hatchback 2012/07942.jpg
# Processing image 7943 of 8041
# Saved /tmp/boundedTest/07943.jpg
# Saved /tmp/processedTest/Audi V8 Sedan 1994/07943.jpg
# Processing image 7944 of 8041
# Saved /tmp/boundedTest/07944.jpg
# Saved /tmp/processedTest/Audi TTS Coupe 2012/07944.jpg
# Processing image 7945 of 8041
# Saved /tmp/boundedTest/07945.jpg
# Saved /tmp/processedTest/Audi RS 4 Convertible 2008/07945.jpg
# Processing image 7946 of 8041
# Saved /tmp/boundedTest/07946.jpg
# Saved /tmp/processedTest/Nissan NV Passenger Van 2012/07946.jpg
# Processing image 7947 of 8041
# Saved /tmp/boundedTest/07947.jpg
# Saved /tmp/processedTest/Rolls-Royce Phantom Drophead Coupe Convertible 2012/07947.jpg
# Processing image 7948 of 8041
# Saved /tmp/boundedTest/07948.jpg
# Saved /tmp/processedTest/AM General Hummer SUV 2000/07948.jpg
# Processing image 7949 of 8041
# Saved /tmp/boundedTest/07949.jpg
# Saved /tmp/processedTest/Dodge Caravan Minivan 1997/07949.jpg
# Processing image 7950 of 8041
# Saved /tmp/boundedTest/07950.jpg
# Saved /tmp/processedTest/Volvo XC90 SUV 2007/07950.jpg
# Processing image 7951 of 8041
# Saved /tmp/boundedTest/07951.jpg
# Saved /tmp/processedTest/Chevrolet Tahoe Hybrid SUV 2012/07951.jpg
# Processing image 7952 of 8041
# Saved /tmp/boundedTest/07952.jpg
# Saved /tmp/processedTest/BMW ActiveHybrid 5 Sedan 2012/07952.jpg
# Processing image 7953 of 8041
# Saved /tmp/boundedTest/07953.jpg
# Saved /tmp/processedTest/Honda Accord Sedan 2012/07953.jpg
# Processing image 7954 of 8041
# Saved /tmp/boundedTest/07954.jpg
# Saved /tmp/processedTest/Plymouth Neon Coupe 1999/07954.jpg
# Processing image 7955 of 8041
# Saved /tmp/boundedTest/07955.jpg
# Saved /tmp/processedTest/Chrysler Crossfire Convertible 2008/07955.jpg
# Processing image 7956 of 8041
# Saved /tmp/boundedTest/07956.jpg
# Saved /tmp/processedTest/Chevrolet HHR SS 2010/07956.jpg
# Processing image 7957 of 8041
# Saved /tmp/boundedTest/07957.jpg
# Saved /tmp/processedTest/GMC Savana Van 2012/07957.jpg
# Processing image 7958 of 8041
# Saved /tmp/boundedTest/07958.jpg
# Saved /tmp/processedTest/Audi S4 Sedan 2007/07958.jpg
# Processing image 7959 of 8041
# Saved /tmp/boundedTest/07959.jpg
# Saved /tmp/processedTest/Ferrari FF Coupe 2012/07959.jpg
# Processing image 7960 of 8041
# Saved /tmp/boundedTest/07960.jpg
# Saved /tmp/processedTest/Volkswagen Golf Hatchback 1991/07960.jpg
# Processing image 7961 of 8041
# Saved /tmp/boundedTest/07961.jpg
# Saved /tmp/processedTest/Fisker Karma Sedan 2012/07961.jpg
# Processing image 7962 of 8041
# Saved /tmp/boundedTest/07962.jpg
# Saved /tmp/processedTest/Ford Focus Sedan 2007/07962.jpg
# Processing image 7963 of 8041
# Saved /tmp/boundedTest/07963.jpg
# Saved /tmp/processedTest/BMW X6 SUV 2012/07963.jpg
# Processing image 7964 of 8041
# Saved /tmp/boundedTest/07964.jpg
# Saved /tmp/processedTest/Jaguar XK XKR 2012/07964.jpg
# Processing image 7965 of 8041
# Saved /tmp/boundedTest/07965.jpg
# Saved /tmp/processedTest/Acura ZDX Hatchback 2012/07965.jpg
# Processing image 7966 of 8041
# Saved /tmp/boundedTest/07966.jpg
# Saved /tmp/processedTest/Chevrolet Malibu Hybrid Sedan 2010/07966.jpg
# Processing image 7967 of 8041
# Saved /tmp/boundedTest/07967.jpg
# Saved /tmp/processedTest/Audi S4 Sedan 2012/07967.jpg
# Processing image 7968 of 8041
# Saved /tmp/boundedTest/07968.jpg
# Saved /tmp/processedTest/Chevrolet Cobalt SS 2010/07968.jpg
# Processing image 7969 of 8041
# Saved /tmp/boundedTest/07969.jpg
# Saved /tmp/processedTest/Volvo C30 Hatchback 2012/07969.jpg
# Processing image 7970 of 8041
# Saved /tmp/boundedTest/07970.jpg
# Saved /tmp/processedTest/Ford Ranger SuperCab 2011/07970.jpg
# Processing image 7971 of 8041
# Saved /tmp/boundedTest/07971.jpg
# Saved /tmp/processedTest/Geo Metro Convertible 1993/07971.jpg
# Processing image 7972 of 8041
# Saved /tmp/boundedTest/07972.jpg
# Saved /tmp/processedTest/Hyundai Azera Sedan 2012/07972.jpg
# Processing image 7973 of 8041
# Saved /tmp/boundedTest/07973.jpg
# Saved /tmp/processedTest/Suzuki SX4 Hatchback 2012/07973.jpg
# Processing image 7974 of 8041
# Saved /tmp/boundedTest/07974.jpg
# Saved /tmp/processedTest/Chevrolet Monte Carlo Coupe 2007/07974.jpg
# Processing image 7975 of 8041
# Saved /tmp/boundedTest/07975.jpg
# Saved /tmp/processedTest/Chevrolet Malibu Hybrid Sedan 2010/07975.jpg
# Processing image 7976 of 8041
# Saved /tmp/boundedTest/07976.jpg
# Saved /tmp/processedTest/Dodge Caravan Minivan 1997/07976.jpg
# Processing image 7977 of 8041
# Saved /tmp/boundedTest/07977.jpg
# Saved /tmp/processedTest/BMW M5 Sedan 2010/07977.jpg
# Processing image 7978 of 8041
# Saved /tmp/boundedTest/07978.jpg
# Saved /tmp/processedTest/Hyundai Genesis Sedan 2012/07978.jpg
# Processing image 7979 of 8041
# Saved /tmp/boundedTest/07979.jpg
# Saved /tmp/processedTest/Audi V8 Sedan 1994/07979.jpg
# Processing image 7980 of 8041
# Saved /tmp/boundedTest/07980.jpg
# Saved /tmp/processedTest/BMW M5 Sedan 2010/07980.jpg
# Processing image 7981 of 8041
# Saved /tmp/boundedTest/07981.jpg
# Saved /tmp/processedTest/Ford Expedition EL SUV 2009/07981.jpg
# Processing image 7982 of 8041
# Saved /tmp/boundedTest/07982.jpg
# Saved /tmp/processedTest/Dodge Challenger SRT8 2011/07982.jpg
# Processing image 7983 of 8041
# Saved /tmp/boundedTest/07983.jpg
# Saved /tmp/processedTest/Volvo XC90 SUV 2007/07983.jpg
# Processing image 7984 of 8041
# Saved /tmp/boundedTest/07984.jpg
# Saved /tmp/processedTest/Chevrolet Traverse SUV 2012/07984.jpg
# Processing image 7985 of 8041
# Saved /tmp/boundedTest/07985.jpg
# Saved /tmp/processedTest/Dodge Dakota Club Cab 2007/07985.jpg
# Processing image 7986 of 8041
# Saved /tmp/boundedTest/07986.jpg
# Saved /tmp/processedTest/Porsche Panamera Sedan 2012/07986.jpg
# Processing image 7987 of 8041
# Saved /tmp/boundedTest/07987.jpg
# Saved /tmp/processedTest/Toyota Camry Sedan 2012/07987.jpg
# Processing image 7988 of 8041
# Saved /tmp/boundedTest/07988.jpg
# Saved /tmp/processedTest/Land Rover LR2 SUV 2012/07988.jpg
# Processing image 7989 of 8041
# Saved /tmp/boundedTest/07989.jpg
# Saved /tmp/processedTest/Aston Martin Virage Convertible 2012/07989.jpg
# Processing image 7990 of 8041
# Saved /tmp/boundedTest/07990.jpg
# Saved /tmp/processedTest/Chrysler 300 SRT-8 2010/07990.jpg
# Processing image 7991 of 8041
# Saved /tmp/boundedTest/07991.jpg
# Saved /tmp/processedTest/Dodge Sprinter Cargo Van 2009/07991.jpg
# Processing image 7992 of 8041
# Saved /tmp/boundedTest/07992.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 2500HD Regular Cab 2012/07992.jpg
# Processing image 7993 of 8041
# Saved /tmp/boundedTest/07993.jpg
# Saved /tmp/processedTest/Chevrolet Impala Sedan 2007/07993.jpg
# Processing image 7994 of 8041
# Saved /tmp/boundedTest/07994.jpg
# Saved /tmp/processedTest/Mercedes-Benz Sprinter Van 2012/07994.jpg
# Processing image 7995 of 8041
# Saved /tmp/boundedTest/07995.jpg
# Saved /tmp/processedTest/GMC Savana Van 2012/07995.jpg
# Processing image 7996 of 8041
# Saved /tmp/boundedTest/07996.jpg
# Saved /tmp/processedTest/GMC Savana Van 2012/07996.jpg
# Processing image 7997 of 8041
# Saved /tmp/boundedTest/07997.jpg
# Saved /tmp/processedTest/Mercedes-Benz 300-Class Convertible 1993/07997.jpg
# Processing image 7998 of 8041
# Saved /tmp/boundedTest/07998.jpg
# Saved /tmp/processedTest/Toyota Sequoia SUV 2012/07998.jpg
# Processing image 7999 of 8041
# Saved /tmp/boundedTest/07999.jpg
# Saved /tmp/processedTest/Jeep Wrangler SUV 2012/07999.jpg
# Processing image 8000 of 8041
# Saved /tmp/boundedTest/08000.jpg
# Saved /tmp/processedTest/Hyundai Tucson SUV 2012/08000.jpg
# Processing image 8001 of 8041
# Saved /tmp/boundedTest/08001.jpg
# Saved /tmp/processedTest/Hyundai Veloster Hatchback 2012/08001.jpg
# Processing image 8002 of 8041
# Saved /tmp/boundedTest/08002.jpg
# Saved /tmp/processedTest/Dodge Dakota Crew Cab 2010/08002.jpg
# Processing image 8003 of 8041
# Saved /tmp/boundedTest/08003.jpg
# Saved /tmp/processedTest/Buick Verano Sedan 2012/08003.jpg
# Processing image 8004 of 8041
# Saved /tmp/boundedTest/08004.jpg
# Saved /tmp/processedTest/Nissan Leaf Hatchback 2012/08004.jpg
# Processing image 8005 of 8041
# Saved /tmp/boundedTest/08005.jpg
# Saved /tmp/processedTest/Ford GT Coupe 2006/08005.jpg
# Processing image 8006 of 8041
# Saved /tmp/boundedTest/08006.jpg
# Saved /tmp/processedTest/Audi RS 4 Convertible 2008/08006.jpg
# Processing image 8007 of 8041
# Saved /tmp/boundedTest/08007.jpg
# Saved /tmp/processedTest/GMC Savana Van 2012/08007.jpg
# Processing image 8008 of 8041
# Saved /tmp/boundedTest/08008.jpg
# Saved /tmp/processedTest/FIAT 500 Convertible 2012/08008.jpg
# Processing image 8009 of 8041
# Saved /tmp/boundedTest/08009.jpg
# Saved /tmp/processedTest/Isuzu Ascender SUV 2008/08009.jpg
# Processing image 8010 of 8041
# Saved /tmp/boundedTest/08010.jpg
# Saved /tmp/processedTest/Suzuki Kizashi Sedan 2012/08010.jpg
# Processing image 8011 of 8041
# Saved /tmp/boundedTest/08011.jpg
# Saved /tmp/processedTest/Daewoo Nubira Wagon 2002/08011.jpg
# Processing image 8012 of 8041
# Saved /tmp/boundedTest/08012.jpg
# Saved /tmp/processedTest/Ferrari FF Coupe 2012/08012.jpg
# Processing image 8013 of 8041
# Saved /tmp/boundedTest/08013.jpg
# Saved /tmp/processedTest/Spyker C8 Convertible 2009/08013.jpg
# Processing image 8014 of 8041
# Saved /tmp/boundedTest/08014.jpg
# Saved /tmp/processedTest/GMC Terrain SUV 2012/08014.jpg
# Processing image 8015 of 8041
# Saved /tmp/boundedTest/08015.jpg
# Saved /tmp/processedTest/Suzuki Aerio Sedan 2007/08015.jpg
# Processing image 8016 of 8041
# Saved /tmp/boundedTest/08016.jpg
# Saved /tmp/processedTest/Volkswagen Beetle Hatchback 2012/08016.jpg
# Processing image 8017 of 8041
# Saved /tmp/boundedTest/08017.jpg
# Saved /tmp/processedTest/Hyundai Veracruz SUV 2012/08017.jpg
# Processing image 8018 of 8041
# Saved /tmp/boundedTest/08018.jpg
# Saved /tmp/processedTest/Dodge Dakota Crew Cab 2010/08018.jpg
# Processing image 8019 of 8041
# Saved /tmp/boundedTest/08019.jpg
# Saved /tmp/processedTest/BMW 1 Series Coupe 2012/08019.jpg
# Processing image 8020 of 8041
# Saved /tmp/boundedTest/08020.jpg
# Saved /tmp/processedTest/Fisker Karma Sedan 2012/08020.jpg
# Processing image 8021 of 8041
# Saved /tmp/boundedTest/08021.jpg
# Saved /tmp/processedTest/Hyundai Tucson SUV 2012/08021.jpg
# Processing image 8022 of 8041
# Saved /tmp/boundedTest/08022.jpg
# Saved /tmp/processedTest/Mercedes-Benz C-Class Sedan 2012/08022.jpg
# Processing image 8023 of 8041
# Saved /tmp/boundedTest/08023.jpg
# Saved /tmp/processedTest/Spyker C8 Convertible 2009/08023.jpg
# Processing image 8024 of 8041
# Saved /tmp/boundedTest/08024.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Extended Cab 2012/08024.jpg
# Processing image 8025 of 8041
# Saved /tmp/boundedTest/08025.jpg
# Saved /tmp/processedTest/Chevrolet Monte Carlo Coupe 2007/08025.jpg
# Processing image 8026 of 8041
# Saved /tmp/boundedTest/08026.jpg
# Saved /tmp/processedTest/Suzuki SX4 Hatchback 2012/08026.jpg
# Processing image 8027 of 8041
# Saved /tmp/boundedTest/08027.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Hybrid Crew Cab 2012/08027.jpg
# Processing image 8028 of 8041
# Saved /tmp/boundedTest/08028.jpg
# Saved /tmp/processedTest/Bentley Arnage Sedan 2009/08028.jpg
# Processing image 8029 of 8041
# Saved /tmp/boundedTest/08029.jpg
# Saved /tmp/processedTest/Audi R8 Coupe 2012/08029.jpg
# Processing image 8030 of 8041
# Saved /tmp/boundedTest/08030.jpg
# Saved /tmp/processedTest/Ford F-150 Regular Cab 2012/08030.jpg
# Processing image 8031 of 8041
# Saved /tmp/boundedTest/08031.jpg
# Saved /tmp/processedTest/Bentley Continental Flying Spur Sedan 2007/08031.jpg
# Processing image 8032 of 8041
# Saved /tmp/boundedTest/08032.jpg
# Saved /tmp/processedTest/Chevrolet Silverado 1500 Regular Cab 2012/08032.jpg
# Processing image 8033 of 8041
# Saved /tmp/boundedTest/08033.jpg
# Saved /tmp/processedTest/Dodge Ram Pickup 3500 Crew Cab 2010/08033.jpg
# Processing image 8034 of 8041
# Saved /tmp/boundedTest/08034.jpg
# Saved /tmp/processedTest/Audi R8 Coupe 2012/08034.jpg
# Processing image 8035 of 8041
# Saved /tmp/boundedTest/08035.jpg
# Saved /tmp/processedTest/AM General Hummer SUV 2000/08035.jpg
# Processing image 8036 of 8041
# Saved /tmp/boundedTest/08036.jpg
# Saved /tmp/processedTest/Suzuki SX4 Sedan 2012/08036.jpg
# Processing image 8037 of 8041
# Saved /tmp/boundedTest/08037.jpg
# Saved /tmp/processedTest/Chevrolet Sonic Sedan 2012/08037.jpg
# Processing image 8038 of 8041
# Saved /tmp/boundedTest/08038.jpg
# Saved /tmp/processedTest/Audi V8 Sedan 1994/08038.jpg
# Processing image 8039 of 8041
# Saved /tmp/boundedTest/08039.jpg
# Saved /tmp/processedTest/Audi 100 Sedan 1994/08039.jpg
# Processing image 8040 of 8041
# Saved /tmp/boundedTest/08040.jpg
# Saved /tmp/processedTest/BMW Z4 Convertible 2012/08040.jpg
# Processing image 8041 of 8041
# Saved /tmp/boundedTest/08041.jpg
# Saved /tmp/processedTest/BMW X5 SUV 2007/08041.jpg
# ------------------------
# Testing images preprocessing complete.

# %% [markdown]
# Data is now saved as follows:
#
# variables: trainLabel, testLabel
#
# preprocessed data directories:
#
# training data: /tmp/processedTrain/Chevrolet Corvette Convertible 2012/06923.jpg
#
# validation data: /tmp/processedValidation/GMC Savana Van 2012/08131.jpg
#
# testing data: /tmp/boundedTest/08040.jpg

# %% [markdown]
# **Preprocessed Image Demo**

# %%
#ORIGINAL TRAIN IMAGE, randomly selected
rand = str(randint(1, len(trainLabels)-2000)).zfill(5)
fname = rand + ".jpg"
print(fname)
f = '/tmp/train/cars_train/' + fname
im1_before = mpimg.imread(f)
imshow(im1_before)
# Out:
# 02715.jpg

# %%
#PROCESSED TRAIN IMAGE
for l in trainLabels:
    if fname == l[5]:
        c_num = int(l[4])
        clAppend = str(classDict.get(c_num)) + '/'
        app = clAppend + fname
        f2 = '/tmp/processedTrain/' + app
        im1_after = mpimg.imread(f2)
        imshow(im1_after)
        break

# %%
#ORIGINAL TEST IMAGE 
im1_before = mpimg.imread("/tmp/test/cars_test/08041.jpg")
imshow(im1_before)

# %%
#PROCESSED TEST IMAGE 
im1_before = mpimg.imread("/tmp/boundedTest/08041.jpg")
imshow(im1_before)

# %% [markdown]
# **Transform and load**

# %%
"""
Prepare dataset for loading into model. First transform images with flips and
rotations for robust model, then create loader with ImageFolder. Images will
be shuffled as well to ensure order doesn't matter.
"""
def getTrainLoad(directory):
    data = datasets.ImageFolder(directory, 
                                transform = transforms.Compose([transforms.Resize((244,244)),
                                transforms.RandomRotation(30),
                                transforms.RandomHorizontalFlip(),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]))
    return torch.utils.data.DataLoader(data, batch_size=128, shuffle=True)

def getTestLoad(directory):
    data = datasets.ImageFolder(directory,
                                transform = transforms.Compose([transforms.Resize((244,244)),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]))
    return torch.utils.data.DataLoader(data, batch_size=32, shuffle=True)
trainLoad = getTrainLoad('/tmp/processedTrain')
validLoad = getTestLoad('/tmp/processedValidation')
testLoad = getTestLoad('/tmp/processedTest/')

# %% [markdown]
# **Transfer Learning - Resnet Implementation**
#
# **Model Creation**

# %%
model = models.resnet34(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 196)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
lrscheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=3, threshold = 0.9)
device = 'cuda'
model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(IntProgress(value=0, max=87306240), HTML(value='')))
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=196, bias=True)
# )

# %% [markdown]
# **Train**

# %%
start = time.time()
epochs = 10
iterations = 0
val = 35
model.to(device)
model.train()

def validation(model, validloader, criterion):
    valid_loss = 0
    accuracy = 0
    model.to(device)
    for i, (images, labels) in enumerate(validloader):
        images, labels = images.to(device), labels.to(device)
        output = model.forward(images)
        valid_loss = valid_loss + criterion(output, labels).item()
        ps = torch.exp(output)
        equality = (labels.data == ps.max(dim=1)[1])
        accuracy = accuracy + equality.type(torch.FloatTensor).mean()
    return valid_loss, accuracy

v_loss_hist = list()
tr_loss_hist = list()
v_acc_hist = list()

for e in range(epochs):
    running_loss = 0
    for i, (inputs, labels) in enumerate(trainLoad):
        iterations += 1
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model.forward(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        #validation
        if iterations % val == 0:
            model.eval()
            with torch.no_grad():
                valid_loss, accuracy = validation(model, validLoad, criterion)
            if (e + 1) > len(v_loss_hist):
                v_loss_hist.append(round(valid_loss/len(validLoad),3))
                tr_loss_hist.append(round(running_loss/val,3))
                v_acc_hist.append(round(float(accuracy/len(validLoad)),3))
            print(f"Epoch #  {e+1}, \
            Valid Loss: {round(valid_loss/len(validLoad),5)}, \
            Training Loss: {round(running_loss/val,5)}, \
            Valid Accuracy: {round(float(accuracy/len(validLoad)),5)}")
            model.train()
            lrscheduler.step(accuracy * 100)
end = time.time()
print("Training Complete.")
print("Training time in seconds:", end - start)
# Out:
# Epoch #  1,             Valid Loss: 5.46001,             Training Loss: 5.18344,             Valid Accuracy: 0.01302
# Epoch #  2,             Valid Loss: 5.69737,             Training Loss: 1.61844,             Valid Accuracy: 0.01823
# Epoch #  2,             Valid Loss: 6.22257,             Training Loss: 4.7054,             Valid Accuracy: 0.03844
# Epoch #  3,             Valid Loss: 6.67163,             Training Loss: 1.76035,             Valid Accuracy: 0.05604
# Epoch #  4,             Valid Loss: 7.26953,             Training Loss: 0.3451,             Valid Accuracy: 0.05208
# Epoch #  4,             Valid Loss: 7.81329,             Training Loss: 1.4016,             Valid Accuracy: 0.0574
# Epoch #  5,             Valid Loss: 8.19199,             Training Loss: 0.49075,             Valid Accuracy: 0.06361
# Epoch #  6,             Valid Loss: 8.42382,             Training Loss: 0.06637,             Valid Accuracy: 0.06969
# Epoch #  6,             Valid Loss: 8.45577,             Training Loss: 0.57035,             Valid Accuracy: 0.0651
# Epoch #  7,             Valid Loss: 8.49142,             Training Loss: 0.26021,             Valid Accuracy: 0.0708
# Epoch #  7,             Valid Loss: 8.58418,             Training Loss: 0.72683,             Valid Accuracy: 0.06969
# Epoch #  8,             Valid Loss: 8.58743,             Training Loss: 0.4451,             Valid Accuracy: 0.06771
# Epoch #  9,             Valid Loss: 8.57254,             Training Loss: 0.18183,             Valid Accuracy: 0.06882
# Epoch #  9,             Valid Loss: 8.57416,             Training Loss: 0.61448,             Valid Accuracy: 0.06955
# Epoch #  10,             Valid Loss: 8.5983,             Training Loss: 0.36104,             Valid Accuracy: 0.06771
# Training Complete.
# Training time in seconds: 828.0973513126373

# %%
plt.plot(tr_loss_hist)
plt.title('Training Loss')
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(v_loss_hist)
plt.title('Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(v_acc_hist)
plt.title('Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Number of epochs')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
model.to(device)
"""
Tests model accuracy with test images
"""
start = time.time()
total = 0
correct = 0
acc_hist = list()
tot_hist = list()
with torch.no_grad():
    for data in testLoad:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, guess = torch.max(outputs.data, 1) 
        total = total + labels.size(0) #total num of images
        correct = correct + (guess == labels).sum().item() #number correct
        acc_hist.append(correct)
        tot_hist.append(total)
end = time.time()
print("Total images tested in model:", len(testLabels))
print("Total accurate predictions:", correct)
print(f"Accuracy of model w/ full test dataset fed: {round(100 * correct / total,8)}%")
print("Testing time in seconds:", end - start)
# Out:
# Total images tested in model: 8041
# Total accurate predictions: 6287
# Accuracy of model w/ full test dataset fed: 78.18679269%
# Testing time in seconds: 55.85551643371582

# %%
plt.plot(acc_hist)
plt.plot(tot_hist)
plt.title('Total Images Tested vs Correct Guesses')
plt.ylabel('# Images Tested')
plt.xlabel('time')
plt.legend(['# correct guesses', '# of images tested'], loc='upper left')
plt.show()

# %% [markdown]
# **Make a CPU copy of the Model for testing**

# %%
#make a copy of the model to change from gpu to cpu.
import copy
model_copy = copy.deepcopy(model)
model_copy.to('cpu')
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=196, bias=True)
# )

# %%
def find_classes(dir):
    classes = os.listdir(dir)
    classes.sort()
    class_to_idx = {classes[i]: i for i in range(len(classes))}
    return classes, class_to_idx
classes, idx = find_classes("/tmp/processedTest/")

def predict(image, model, topk=5):
    #open image and change to np form//cpu consideration
    pil_in = PIL.Image.open(image)
    transform = transforms.Compose([transforms.Resize((244,244)),
                                    transforms.CenterCrop(224),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406], 
                                                         [0.229, 0.224, 0.225])])
    pilTrans = transform(pil_in)
    img = np.array(pilTrans)
    img_tensor = torch.from_numpy(img).type(torch.FloatTensor) #np to tensor
    dimen = img_tensor.unsqueeze_(0)
    model.eval()
    with torch.no_grad():
        output = model.forward(dimen)
    probs_top = output.topk(topk)[0]
    top_prediction = output.topk(topk)[1]
    p = np.array(top_prediction)[0]
    o_guesses = np.array(top_prediction)[0]
    return p, o_guesses

# %% [markdown]
# **Randomly pick a test image to predict**

# %%
random_test_image = str(str(randint(1, len(testLabels))).zfill(5)) + '.jpg'
image_to_classify = "/tmp/boundedTest/" + random_test_image
device = ('cpu')
start = time.time()
tp, ps = predict(image_to_classify, model_copy, topk=5)
print("Randomly chosen file to classify:",image_to_classify)
end = time.time()
print("Seconds elapsed for prediction:", end - start)
print("*******************************")
print("FIRST GUESS: ",classes[ps[0]])
print("*******************************")
print("Might also be:", classes[ps[1]])
print("Might also be:", classes[ps[2]])
print("Might also be:", classes[ps[3]])
print("Might also be:", classes[ps[4]], "\n")
gimg = mpimg.imread(image_to_classify)
imshow(gimg)
# Out:
# Randomly chosen file to classify: /tmp/boundedTest/00109.jpg
# Seconds elapsed for prediction: 0.1431119441986084
# *******************************
# FIRST GUESS:  BMW 3 Series Wagon 2012
# *******************************
# Might also be: Daewoo Nubira Wagon 2002
# Might also be: BMW 1 Series Coupe 2012
# Might also be: BMW 3 Series Sedan 2012
# Might also be: Acura Integra Type R 2001
